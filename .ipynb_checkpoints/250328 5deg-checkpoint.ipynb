# %% [markdown]
# # Install and load modules

# %%
# !uv pip install "vegafusion[embed]>=1.5.0" shapely polars matplotlib hvplot scikit-learn
# Out:
# Using Python 3.14.2 environment at: /home/max/general
# Audited 6 packages in 4ms

# %%
import polars as pl
import matplotlib.pyplot as plt
import os
import altair as alt
import numpy as np
#import numpy.polynomial
from shapely.geometry import Polygon
import hvplot.polars
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e94e065e-9da9-48a7-bbaf-f0c67628131d'>
#   <div id="a55d4bd5-b25b-42bd-86b9-a1e4f70ccf26" data-root-id="e94e065e-9da9-48a7-bbaf-f0c67628131d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"edd25723-6f4e-4e1f-84a2-073dbe0e3252":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"a0f7eb48-26bc-4675-8c32-89721e3b3fc1","attributes":{"notifications":{"type":"object","name":"Notifications","id":"9d851e6f-1be7-4a1b-b9b8-c1c4c96af1a7"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e94e065e-9da9-48a7-bbaf-f0c67628131d"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"95eea513-0d09-4a4b-a45d-8b9f4ef548a9","attributes":{"plot_id":"e94e065e-9da9-48a7-bbaf-f0c67628131d","comm_id":"2d4d729a674941f3bd9e507f167107db","client_comm_id":"61466c92f721480b98061fc054a3db6f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"edd25723-6f4e-4e1f-84a2-073dbe0e3252","roots":{"e94e065e-9da9-48a7-bbaf-f0c67628131d":"a55d4bd5-b25b-42bd-86b9-a1e4f70ccf26"},"root_ids":["e94e065e-9da9-48a7-bbaf-f0c67628131d"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
rc = lambda r,c:pl.Config(set_tbl_rows=r,set_tbl_cols=c)

# %% [markdown]
# # Load data

# %% [markdown]
# ## Batch files

# %%
def read_batch_file(path):
    start = pl.read_csv(path).with_row_index().filter(pl.col('[Header]')=='[Batch Table]')['index'][0]+2
    nrows = int(pl.read_csv(path,
                skip_rows=start,has_header=False,n_rows=1)[0,0].split('\t')[-1])
    return pl.read_csv(path,
                skip_rows=start+1,has_header=True,n_rows=nrows,separator='\t')

# %%
b0 = read_batch_file('Processed data/batch files/240428-std curve.txt')
b1 = read_batch_file('Processed data/batch files/250328 4d sol.txt')

batch = pl.concat([b0,b1])
batch
# Out:
# shape: (28, 45)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬───┬─────┬─────┬─────┬─────┬─────┬────────┬───────┐
# │ Run ┆ Tra ┆ Via ┆ Sam ┆ Sam ┆ Sam ┆ Ana ┆ Met ┆ … ┆ Opt ┆ Opt ┆ Sys ┆ Mul ┆ Bar ┆ Sample ┆ Conc. │
# │ Mod ┆ y   ┆ l#  ┆ ple ┆ ple ┆ ple ┆ lys ┆ hod ┆   ┆ ion ┆ ion ┆ tem ┆ ti  ┆ cod ┆ r File ┆ Overr │
# │ e   ┆ Nam ┆ --- ┆ Nam ┆ ID  ┆ Typ ┆ is  ┆ Fil ┆   ┆ 9   ┆ 10  ┆ Sui ┆ Inj ┆ e   ┆ ---    ┆ ides  │
# │ --- ┆ e   ┆ str ┆ e   ┆ --- ┆ e   ┆ Typ ┆ e   ┆   ┆ --- ┆ --- ┆ tab ┆ ect ┆ --- ┆ str    ┆ ---   │
# │ str ┆ --- ┆     ┆ --- ┆ i64 ┆ --- ┆ e   ┆ --- ┆   ┆ str ┆ str ┆ ili ┆ ion ┆ str ┆        ┆ str   │
# │     ┆ str ┆     ┆ str ┆     ┆ str ┆ --- ┆ str ┆   ┆     ┆     ┆ ty  ┆ --- ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆ str ┆     ┆   ┆     ┆     ┆ --- ┆ i64 ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆ i64 ┆     ┆     ┆        ┆       │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═══╪═════╪═════╪═════╪═════╪═════╪════════╪═══════╡
# │ DL  ┆ 1   ┆ -1  ┆ non ┆ 1   ┆ 2:C ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ e   ┆     ┆ ont ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆     ┆     ┆ rol ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ A2  ┆ buf ┆ 1   ┆ 2:C ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ fer ┆     ┆ ont ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆     ┆     ┆ rol ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ B2  ┆ 0.1 ┆ 1   ┆ 1:S ┆ nul ┆ Bio ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ 1pm ┆     ┆ tan ┆ l   ┆ She ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ol  ┆     ┆ dar ┆     ┆ ll_ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ ABm ┆     ┆ d:( ┆     ┆ AB( ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ I)  ┆     ┆ M1- ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ 42) ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _MS ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _QC ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ +Qu ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ant ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ B2  ┆ 0.1 ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ 1pm ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ol  ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ ABm ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ B2  ┆ 0.3 ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ 3pm ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ol  ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ ABm ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ B2  ┆ 0.3 ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ 3pm ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ol  ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ ABm ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ B2  ┆ 1pm ┆ 1   ┆ 1:S ┆ nul ┆ Bio ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ She ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ ll_ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ AB( ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ M1- ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 42) ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _MS ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _QC ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ +Qu ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ant ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ B2  ┆ 1pm ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ C2  ┆ 3pm ┆ 1   ┆ 1:S ┆ nul ┆ Bio ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ She ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ ll_ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ AB( ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ M1- ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 42) ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _MS ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _QC ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ +Qu ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ant ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ C2  ┆ 3pm ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ C2  ┆ 9pm ┆ 1   ┆ 1:S ┆ nul ┆ Bio ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ She ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ ll_ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ AB( ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ M1- ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 42) ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _MS ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _QC ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ +Qu ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ant ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ C2  ┆ 9pm ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ C2  ┆ 27p ┆ 1   ┆ 1:S ┆ nul ┆ Bio ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ mol ┆     ┆ tan ┆ l   ┆ She ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ ll_ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ AB( ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ M1- ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 42) ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _MS ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _QC ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ +Qu ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ant ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ C2  ┆ 27p ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ mol ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ -1  ┆ non ┆ 1   ┆ 2:C ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ e   ┆     ┆ ont ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆     ┆     ┆ rol ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ -1  ┆ non ┆ 1   ┆ 2:C ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ e   ┆     ┆ ont ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆     ┆     ┆ rol ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ A7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_5 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ 0uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ _1  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ A7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_5 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ 0uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ _2  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ B7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_2 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ 5uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ _1  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ C7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_1 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ 2uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ _1  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ D7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_5 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ 0uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ _3  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ E7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_2 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ 5uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ _2  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ F7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_1 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ 2uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ _2  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ G7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_5 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ 0uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ _4  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ H7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_2 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ 5uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ _3  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ A8  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_1 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆ 2uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆ _3  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ B8  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ g_B ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆     ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ DL  ┆ 1   ┆ -1  ┆ cle ┆ 1   ┆ 2:C ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ 0   ┆ 1   ┆ nul ┆ null   ┆ null  │
# │ AQ  ┆     ┆     ┆ an  ┆     ┆ ont ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆     ┆     ┆ l   ┆        ┆       │
# │ DP  ┆     ┆     ┆     ┆     ┆ rol ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴───┴─────┴─────┴─────┴─────┴─────┴────────┴───────┘

# %%
batch=batch.rename({'Data File':'Data Filename'})

# %% [markdown]
# ## UV

# %%
summary205 = pl.read_csv('Processed data/250328 5deg sol/All 205nm reprocessed 260120.txt',
                         skip_rows=2,separator='\t',null_values='-----').drop_nulls('Sample Type')
summary205
# Out:
# shape: (25, 17)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬───┬─────┬─────┬─────┬─────┬─────┬────────┬───────┐
# │     ┆ Dat ┆ Sam ┆ Sam ┆ Via ┆ Ret ┆ Are ┆ Con ┆ … ┆ Acc ┆ Cal ┆ Pea ┆ Pea ┆ Qua ┆ S/N    ┆ Taili │
# │ --- ┆ a   ┆ ple ┆ ple ┆ l#  ┆ .   ┆ a   ┆ c.  ┆   ┆ ura ┆ .   ┆ k   ┆ k   ┆ nt. ┆ ---    ┆ ng F. │
# │ i64 ┆ Fil ┆ Typ ┆ Nam ┆ --- ┆ Tim ┆ --- ┆ --- ┆   ┆ cy[ ┆ Poi ┆ Sta ┆ End ┆ Lim ┆ f64    ┆ ---   │
# │     ┆ ena ┆ e   ┆ e   ┆ str ┆ e   ┆ f64 ┆ f64 ┆   ┆ %]  ┆ nt  ┆ rt  ┆ --- ┆ it( ┆        ┆ f64   │
# │     ┆ me  ┆ --- ┆ --- ┆     ┆ --- ┆     ┆     ┆   ┆ --- ┆ --- ┆ --- ┆ f64 ┆ QL) ┆        ┆       │
# │     ┆ --- ┆ str ┆ str ┆     ┆ f64 ┆     ┆     ┆   ┆ f64 ┆ str ┆ f64 ┆     ┆ --- ┆        ┆       │
# │     ┆ str ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆ f64 ┆        ┆       │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═══╪═════╪═════╪═════╪═════╪═════╪════════╪═══════╡
# │ 1   ┆ 240 ┆ Sta ┆ 0.1 ┆ B2  ┆ 4.3 ┆ 187 ┆ 0.0 ┆ … ┆ 72. ┆ *   ┆ 4.3 ┆ 4.4 ┆ 0.0 ┆ 29.01  ┆ 1.099 │
# │     ┆ 428 ┆ nda ┆ 1pm ┆     ┆ 95  ┆ 2.0 ┆ 79  ┆   ┆ 1   ┆     ┆ 62  ┆ 45  ┆ 3   ┆        ┆       │
# │     ┆ -st ┆ rd( ┆ ol  ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ d   ┆ Cal ┆ ABm ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ cur ┆ c.P ┆ 1-4 ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ ve_ ┆ oin ┆ 2   ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 0.1 ┆ t)  ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 1pm ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ ol  ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ ABm ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 1…  ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ 2   ┆ 240 ┆ Sta ┆ 0.1 ┆ B2  ┆ 4.3 ┆ 208 ┆ 0.0 ┆ … ┆ 79. ┆ *   ┆ 4.3 ┆ 4.4 ┆ 0.0 ┆ 24.76  ┆ 1.176 │
# │     ┆ 428 ┆ nda ┆ 1pm ┆     ┆ 97  ┆ 6.0 ┆ 88  ┆   ┆ 8   ┆     ┆ 47  ┆ 35  ┆ 4   ┆        ┆       │
# │     ┆ -st ┆ rd( ┆ ol  ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ d   ┆ Cal ┆ ABm ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ cur ┆ c.P ┆ 1-4 ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ ve_ ┆ oin ┆ 2   ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 0.1 ┆ t)  ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 1pm ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ ol  ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ ABm ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 1…  ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ 3   ┆ 240 ┆ Sta ┆ 0.3 ┆ B2  ┆ 4.4 ┆ 936 ┆ 0.3 ┆ … ┆ 113 ┆ *   ┆ 4.3 ┆ 4.5 ┆ 0.0 ┆ 93.19  ┆ 1.737 │
# │     ┆ 428 ┆ nda ┆ 3pm ┆     ┆ 12  ┆ 3.0 ┆ 75  ┆   ┆ .6  ┆     ┆ 57  ┆ 45  ┆ 4   ┆        ┆       │
# │     ┆ -st ┆ rd( ┆ ol  ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ d   ┆ Cal ┆ ABm ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ cur ┆ c.P ┆ 1-4 ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ ve_ ┆ oin ┆ 2   ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 0.3 ┆ t)  ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 3pm ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ ol  ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ ABm ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 1…  ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │

# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬───┬─────┬─────┬─────┬─────┬─────┬──────┬─────────┐
# │ Run ┆ Tra ┆ Via ┆ Sam ┆ Sam ┆ Sam ┆ Ana ┆ Met ┆ … ┆ Acc ┆ Cal ┆ Pea ┆ Pea ┆ Qua ┆ S/N  ┆ Tailing │
# │ Mod ┆ y   ┆ l#  ┆ ple ┆ ple ┆ ple ┆ lys ┆ hod ┆   ┆ ura ┆ .   ┆ k   ┆ k   ┆ nt. ┆ ---  ┆ F.      │
# │ e   ┆ Nam ┆ --- ┆ Nam ┆ ID  ┆ Typ ┆ is  ┆ Fil ┆   ┆ cy[ ┆ Poi ┆ Sta ┆ End ┆ Lim ┆ f64  ┆ ---     │
# │ --- ┆ e   ┆ str ┆ e   ┆ --- ┆ e   ┆ Typ ┆ e   ┆   ┆ %]  ┆ nt  ┆ rt  ┆ --- ┆ it( ┆      ┆ f64     │
# │ str ┆ --- ┆     ┆ --- ┆ i64 ┆ --- ┆ e   ┆ --- ┆   ┆ --- ┆ --- ┆ --- ┆ f64 ┆ QL) ┆      ┆         │
# │     ┆ str ┆     ┆ str ┆     ┆ str ┆ --- ┆ str ┆   ┆ f64 ┆ str ┆ f64 ┆     ┆ --- ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆ str ┆     ┆   ┆     ┆     ┆     ┆     ┆ f64 ┆      ┆         │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═══╪═════╪═════╪═════╪═════╪═════╪══════╪═════════╡
# │ DL  ┆ 1   ┆ -1  ┆ cle ┆ 1   ┆ 2:C ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ an  ┆     ┆ ont ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆     ┆     ┆ rol ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ -1  ┆ non ┆ 1   ┆ 2:C ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ e   ┆     ┆ ont ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆     ┆     ┆ rol ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ -1  ┆ non ┆ 1   ┆ 2:C ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ e   ┆     ┆ ont ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆     ┆     ┆ rol ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ -1  ┆ non ┆ 1   ┆ 2:C ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ e   ┆     ┆ ont ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆     ┆     ┆ rol ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ A2  ┆ buf ┆ 1   ┆ 2:C ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ fer ┆     ┆ ont ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆     ┆     ┆ rol ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ A7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_5 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ 0uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ _1  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ A7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_5 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ 0uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ _2  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ A8  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_1 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ 2uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ _3  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ B2  ┆ 0.1 ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ 1pm ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ol  ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ ABm ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ B2  ┆ 0.1 ┆ 1   ┆ 1:S ┆ nul ┆ Bio ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ 1pm ┆     ┆ tan ┆ l   ┆ She ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ol  ┆     ┆ dar ┆     ┆ ll_ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ ABm ┆     ┆ d:( ┆     ┆ AB( ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ I)  ┆     ┆ M1- ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ 42) ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _MS ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _QC ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ +Qu ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ant ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ B2  ┆ 0.3 ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ 3pm ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ol  ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ ABm ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ B2  ┆ 0.3 ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ 3pm ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ol  ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ ABm ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ B2  ┆ 1pm ┆ 1   ┆ 1:S ┆ nul ┆ Bio ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ She ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ ll_ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ AB( ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ M1- ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 42) ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _MS ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _QC ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ +Qu ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ant ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ B2  ┆ 1pm ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ B7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_2 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ 5uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ _1  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ B8  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_B ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆     ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ C2  ┆ 27p ┆ 1   ┆ 1:S ┆ nul ┆ Bio ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ mol ┆     ┆ tan ┆ l   ┆ She ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ ll_ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ AB( ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ M1- ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 42) ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _MS ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _QC ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ +Qu ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ant ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ C2  ┆ 27p ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ mol ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ C2  ┆ 3pm ┆ 1   ┆ 1:S ┆ nul ┆ Bio ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ She ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ ll_ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ AB( ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ M1- ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 42) ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _MS ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _QC ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ +Qu ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ant ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ C2  ┆ 3pm ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ C2  ┆ 9pm ┆ 1   ┆ 1:S ┆ nul ┆ Bio ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ She ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ ll_ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ AB( ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ M1- ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 42) ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _MS ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _QC ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ +Qu ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ant ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ C2  ┆ 9pm ┆ 1   ┆ 1:S ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ ol  ┆     ┆ tan ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ ABm ┆     ┆ dar ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 1-4 ┆     ┆ d   ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ 2   ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ C7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_1 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ 2uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ _1  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ D7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_5 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ 0uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ _3  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ E7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_2 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ 5uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ _2  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ F7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_1 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ 2uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ _2  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ G7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_5 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ 0uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ _4  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │ DL  ┆ 1   ┆ H7  ┆ 5de ┆ 1   ┆ 0:U ┆ nul ┆ C:\ ┆ … ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ null ┆ null    │
# │ AQ  ┆     ┆     ┆ g_2 ┆     ┆ nkn ┆ l   ┆ Lab ┆   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆      ┆         │
# │ DP  ┆     ┆     ┆ 5uM ┆     ┆ own ┆     ┆ Sol ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆ _3  ┆     ┆     ┆     ┆ uti ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ons ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Da ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Max ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \Bi ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oSh ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ …   ┆   ┆     ┆     ┆     ┆     ┆     ┆      ┆         │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴───┴─────┴─────┴─────┴─────┴─────┴──────┴─────────┘

# %%
batch.columns
# Out:
# ['Run Mode',
#  'Tray Name',
#  'Vial#',
#  'Sample Name',
#  'Sample ID',
#  'Sample Type',
#  'Analysis Type',
#  'Method File',
#  'Data Filename',
#  'Background',
#  'Background Data File',
#  'Level#',
#  'Inj. Volume',
#  'ISTD Amt.',
#  'Sample Amt.',
#  'Dil. Factor',
#  'System Check',
#  'Report Output',
#  'Report Format File',
#  'User Prog.',
#  'Action',
#  'Data Comment',
#  'AutoPurge',
#  'Baseline Check',
#  'Option 1',
#  'Option 2',
#  'Option 3',
#  'Option 4',
#  'Option 5',
#  'Custom Parameters',
#  'Auto Tuning',
#  'Tuning File',
#  'PsiPort Instrument Method File',
#  'Summary Type',
#  'Summary Report Format File',
#  'Option 6',
#  'Option 7',
#  'Option 8',
#  'Option 9',
#  'Option 10',
#  'System Suitability',
#  'Multi Injection',
#  'Barcode',
#  'Sampler File',
#  'Conc. Overrides']

# %%
summary205.columns
# Out:
# ['',
#  'Data Filename',
#  'Sample Type',
#  'Sample Name',
#  'Vial#',
#  'Ret. Time',
#  'Area',
#  'Conc.',
#  'Height',
#  'Std. Conc.',
#  'Accuracy[%]',
#  'Cal. Point',
#  'Peak Start',
#  'Peak End',
#  'Quant. Limit(QL)',
#  'S/N',
#  'Tailing F.']

# %%
rc(30,15)

# %%
UV = pl.concat([batch.select(['Vial#','Sample Name','Inj. Volume','Method File','Data Filename'])
,summary205.select(['Data Filename','Sample Type', 'Sample Name', 'Vial#',
                    'Ret. Time', 'Area', 'Conc.', 'Height','Peak Start',
 'Peak End','Std. Conc.'])]
           ,how='align_full')#.filter(pl.col('Sample Name').str.contains('pmol'))
#.drop_nulls('Inj. Volume')#.drop_nulls('Area')
UV
# Out:
# shape: (28, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ Via ┆ Sam ┆ Inj ┆ Method ┆ Data  ┆ Sampl ┆ Ret.  ┆ Area  ┆ Conc. ┆ Heigh ┆ Peak  ┆ Peak  ┆ Std.  │
# │ l#  ┆ ple ┆ .   ┆ File   ┆ Filen ┆ e     ┆ Time  ┆ ---   ┆ ---   ┆ t     ┆ Start ┆ End   ┆ Conc. │
# │ --- ┆ Nam ┆ Vol ┆ ---    ┆ ame   ┆ Type  ┆ ---   ┆ f64   ┆ f64   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ str ┆ e   ┆ ume ┆ str    ┆ ---   ┆ ---   ┆ f64   ┆       ┆       ┆ f64   ┆ f64   ┆ f64   ┆ f64   │
# │     ┆ --- ┆ --- ┆        ┆ str   ┆ str   ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ str ┆ f64 ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ -1  ┆ cle ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Contr ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ an  ┆ 0   ┆ Soluti ┆ 8 4d  ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ sol_c ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ lean_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 001_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 2.lcd ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _none ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 01.l… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _none ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 15.l… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Contr ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8 4d  ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ sol_n ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ one_0 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 01_01 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ .lcd  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A2  ┆ buf ┆ 30. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ fer ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _buff ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ er_00 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1_02… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A7  ┆ 5de ┆ 2.0 ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.468 ┆ 8625. ┆ 0.346 ┆ 4091. ┆ 4.403 ┆ 4.558 ┆ null  │
# │     ┆ g_5 ┆     ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A7  ┆ 5de ┆ 8.0 ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.468 ┆ 47994 ┆ 1.898 ┆ 19056 ┆ 4.205 ┆ 4.55  ┆ null  │
# │     ┆ g_5 ┆     ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A8  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.467 ┆ 47273 ┆ 1.87  ┆ 19347 ┆ 4.203 ┆ 4.55  ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.1 ┆ 3.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.397 ┆ 2086. ┆ 0.088 ┆ 1277. ┆ 4.347 ┆ 4.435 ┆ 0.11  │
# │     ┆ 1pm ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ _MS_QC ┆ _0.11 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ +Quant ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.1 ┆ 3.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.395 ┆ 1872. ┆ 0.079 ┆ 1227. ┆ 4.362 ┆ 4.445 ┆ 0.11  │
# │     ┆ 1pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.11 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.3 ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.407 ┆ 9840. ┆ 0.394 ┆ 4726. ┆ 4.33  ┆ 4.488 ┆ 0.33  │
# │     ┆ 3pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.33 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.3 ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.412 ┆ 9363. ┆ 0.375 ┆ 4412. ┆ 4.357 ┆ 4.545 ┆ 0.33  │
# │     ┆ 3pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.33 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 1pm ┆ 27. ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.405 ┆ 26554 ┆ 1.053 ┆ 13510 ┆ 4.343 ┆ 4.49  ┆ 1.0   │
# │     ┆ ol  ┆ 0   ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _1pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 1pm ┆ 27. ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.41  ┆ 26119 ┆ 1.036 ┆ 13193 ┆ 4.34  ┆ 4.492 ┆ 1.0   │
# │     ┆ ol  ┆ 0   ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _1pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.458 ┆ 15750 ┆ 0.627 ┆ 6109. ┆ 4.218 ┆ 4.542 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B8  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ g_B ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ deg_B ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 11.lc ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 27p ┆ 27. ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.4   ┆ 68051 ┆ 26.84 ┆ 30419 ┆ 4.095 ┆ 4.607 ┆ 27.0  │
# │     ┆ mol ┆ 0   ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 2.0   ┆ 5     ┆ 3.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _27pm ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ ABm1- ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ 4…    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 27p ┆ 27. ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.4   ┆ 67259 ┆ 26.53 ┆ 28948 ┆ 4.137 ┆ 4.605 ┆ 27.0  │
# │     ┆ mol ┆ 0   ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 3.0   ┆ 3     ┆ 1.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _27pm ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ ABm1- ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ 4…    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 3pm ┆ 3.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.4   ┆ 82947 ┆ 3.277 ┆ 33894 ┆ 4.135 ┆ 4.567 ┆ 3.0   │
# │     ┆ ol  ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _3pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 3pm ┆ 3.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.402 ┆ 72895 ┆ 2.88  ┆ 33999 ┆ 4.155 ┆ 4.485 ┆ 3.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _3pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.407 ┆ 23130 ┆ 9.128 ┆ 10651 ┆ 4.158 ┆ 4.592 ┆ 9.0   │
# │     ┆ ol  ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 0.0   ┆       ┆ 3.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.403 ┆ 23295 ┆ 9.193 ┆ 10752 ┆ 4.14  ┆ 4.588 ┆ 9.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0.0   ┆       ┆ 7.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.468 ┆ 47662 ┆ 1.885 ┆ 20537 ┆ 4.215 ┆ 4.552 ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ D7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.463 ┆ 6908. ┆ 0.278 ┆ 2789. ┆ 4.402 ┆ 4.595 ┆ null  │
# │     ┆ g_5 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ E7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.465 ┆ 11250 ┆ 0.449 ┆ 4403. ┆ 4.2   ┆ 4.538 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ F7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.458 ┆ 54012 ┆ 2.136 ┆ 22734 ┆ 4.203 ┆ 4.542 ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ G7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.463 ┆ 54544 ┆ 2.157 ┆ 23531 ┆ 4.207 ┆ 4.548 ┆ null  │
# │     ┆ g_5 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _4  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ H7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.458 ┆ 11628 ┆ 0.464 ┆ 5990. ┆ 4.395 ┆ 4.547 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
UV.filter(pl.col('Sample Name').str.contains('_B')).mean()
# Out:
# shape: (1, 13)
# ┌─────┬─────┬─────┬────────┬────────┬───────┬───────┬──────┬───────┬───────┬───────┬───────┬───────┐
# │ Via ┆ Sam ┆ Inj ┆ Method ┆ Data   ┆ Sampl ┆ Ret.  ┆ Area ┆ Conc. ┆ Heigh ┆ Peak  ┆ Peak  ┆ Std.  │
# │ l#  ┆ ple ┆ .   ┆ File   ┆ Filena ┆ e     ┆ Time  ┆ ---  ┆ ---   ┆ t     ┆ Start ┆ End   ┆ Conc. │
# │ --- ┆ Nam ┆ Vol ┆ ---    ┆ me     ┆ Type  ┆ ---   ┆ f64  ┆ f64   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ str ┆ e   ┆ ume ┆ str    ┆ ---    ┆ ---   ┆ f64   ┆      ┆       ┆ f64   ┆ f64   ┆ f64   ┆ f64   │
# │     ┆ --- ┆ --- ┆        ┆ str    ┆ str   ┆       ┆      ┆       ┆       ┆       ┆       ┆       │
# │     ┆ str ┆ f64 ┆        ┆        ┆       ┆       ┆      ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪════════╪═══════╪═══════╪══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ nul ┆ nul ┆ 10. ┆ null   ┆ null   ┆ null  ┆ null  ┆ null ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │ l   ┆ l   ┆ 0   ┆        ┆        ┆       ┆       ┆      ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴────────┴───────┴───────┴──────┴───────┴───────┴───────┴───────┴───────┘

# %%
UV.filter(pl.col('Sample Name').str.contains('12'))
# Out:
# shape: (3, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ Via ┆ Sam ┆ Inj ┆ Method ┆ Data  ┆ Sampl ┆ Ret.  ┆ Area  ┆ Conc. ┆ Heigh ┆ Peak  ┆ Peak  ┆ Std.  │
# │ l#  ┆ ple ┆ .   ┆ File   ┆ Filen ┆ e     ┆ Time  ┆ ---   ┆ ---   ┆ t     ┆ Start ┆ End   ┆ Conc. │
# │ --- ┆ Nam ┆ Vol ┆ ---    ┆ ame   ┆ Type  ┆ ---   ┆ f64   ┆ f64   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ str ┆ e   ┆ ume ┆ str    ┆ ---   ┆ ---   ┆ f64   ┆       ┆       ┆ f64   ┆ f64   ┆ f64   ┆ f64   │
# │     ┆ --- ┆ --- ┆        ┆ str   ┆ str   ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ str ┆ f64 ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ A8  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.467 ┆ 47273 ┆ 1.87  ┆ 19347 ┆ 4.203 ┆ 4.55  ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.468 ┆ 47662 ┆ 1.885 ┆ 20537 ┆ 4.215 ┆ 4.552 ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ F7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.458 ┆ 54012 ┆ 2.136 ┆ 22734 ┆ 4.203 ┆ 4.542 ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %% [markdown]
# ## MS

# %%
summaryMS = pl.read_csv('Processed data/250328 5deg sol/All MS reprocessed 260120.txt',
                        skip_rows=2,separator='\t',null_values='-----').drop_nulls('Sample Type')
summaryMS
# Out:
# shape: (25, 17)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬───┬─────┬─────┬─────┬─────┬─────┬────────┬───────┐
# │     ┆ Dat ┆ Sam ┆ Sam ┆ Via ┆ Ret ┆ Are ┆ Con ┆ … ┆ Acc ┆ Cal ┆ Pea ┆ Pea ┆ Qua ┆ S/N    ┆ Taili │
# │ --- ┆ a   ┆ ple ┆ ple ┆ l#  ┆ .   ┆ a   ┆ c.  ┆   ┆ ura ┆ .   ┆ k   ┆ k   ┆ nt. ┆ ---    ┆ ng F. │
# │ i64 ┆ Fil ┆ Typ ┆ Nam ┆ --- ┆ Tim ┆ --- ┆ --- ┆   ┆ cy[ ┆ Poi ┆ Sta ┆ End ┆ Lim ┆ f64    ┆ ---   │
# │     ┆ ena ┆ e   ┆ e   ┆ str ┆ e   ┆ f64 ┆ f64 ┆   ┆ %]  ┆ nt  ┆ rt  ┆ --- ┆ it( ┆        ┆ str   │
# │     ┆ me  ┆ --- ┆ --- ┆     ┆ --- ┆     ┆     ┆   ┆ --- ┆ --- ┆ --- ┆ f64 ┆ QL) ┆        ┆       │
# │     ┆ --- ┆ str ┆ str ┆     ┆ f64 ┆     ┆     ┆   ┆ f64 ┆ str ┆ f64 ┆     ┆ --- ┆        ┆       │
# │     ┆ str ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆ f64 ┆        ┆       │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═══╪═════╪═════╪═════╪═════╪═════╪════════╪═══════╡
# │ 1   ┆ 240 ┆ Sta ┆ 0.1 ┆ B2  ┆ 4.4 ┆ 711 ┆ 0.0 ┆ … ┆ 61. ┆ *   ┆ 4.3 ┆ 4.5 ┆ 0
┆ 2.1 ┆ … ┆ nul ┆ nul ┆ 4.3 ┆ 5.1 ┆ 0.7 ┆ 26.96  ┆ 1.449 │
# │     ┆ 328 ┆ now ┆ g_1 ┆     ┆ 74  ┆ 250 ┆ 14  ┆   ┆ l   ┆ l   ┆ 5   ┆ 5   ┆ 8   ┆        ┆       │
# │     ┆ 4d  ┆ n   ┆ 2uM ┆     ┆     ┆ .0  ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ sol ┆     ┆ _2  ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ _5d ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ eg_ ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 12u ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ M_2 ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ _00 ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 1_… ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │ 25  ┆ 250 ┆ Unk ┆ 5de ┆ C7  ┆ 4.4 ┆ 102 ┆ 1.9 ┆ … ┆ nul ┆ nul ┆ 4.4 ┆ 4.7 ┆ 1.5 ┆ 12.65  ┆ 1.344 │
# │     ┆ 328 ┆ now ┆ g_1 ┆     ┆ 84  ┆ 131 ┆ 9   ┆   ┆ l   ┆ l   ┆     ┆ 83  ┆ 7   ┆        ┆       │
# │     ┆ 4d  ┆ n   ┆ 2uM ┆     ┆     ┆ .0  ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ sol ┆     ┆ _1  ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ _5d ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ eg_ ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 12u ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ M_1 ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ _00 ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# │     ┆ 1_… ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆        ┆       │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴───┴─────┴─────┴─────┴─────┴─────┴────────┴───────┘

# %%
MS = pl.concat([batch.select(['Vial#','Sample Name','Inj. Volume','Method File','Data Filename'])
,summaryMS.select(['Data Filename','Sample Type', 'Sample Name', 'Vial#',
                    'Ret. Time', 'Area', 'Conc.', 'Height','Peak Start',
 'Peak End','Std. Conc.'])]
           ,how='align_full')#.filter(pl.col('Sample Name').str.contains('pmol'))
#.drop_nulls('Inj. Volume')#.drop_nulls('Area')
MS
# Out:
# shape: (28, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ Via ┆ Sam ┆ Inj ┆ Method ┆ Data  ┆ Sampl ┆ Ret.  ┆ Area  ┆ Conc. ┆ Heigh ┆ Peak  ┆ Peak  ┆ Std.  │
# │ l#  ┆ ple ┆ .   ┆ File   ┆ Filen ┆ e     ┆ Time  ┆ ---   ┆ ---   ┆ t     ┆ Start ┆ End   ┆ Conc. │
# │ --- ┆ Nam ┆ Vol ┆ ---    ┆ ame   ┆ Type  ┆ ---   ┆ f64   ┆ f64   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ str ┆ e   ┆ ume ┆ str    ┆ ---   ┆ ---   ┆ f64   ┆       ┆       ┆ f64   ┆ f64   ┆ f64   ┆ f64   │
# │     ┆ --- ┆ --- ┆        ┆ str   ┆ str   ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ str ┆ f64 ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ -1  ┆ cle ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Contr ┆ 4.283 ┆ 533.0 ┆ -0.06 ┆ 72.0  ┆ 4.25  ┆ 4.517 ┆ null  │
# │     ┆ an  ┆ 0   ┆ Soluti ┆ 8 4d  ┆ ol    ┆       ┆       ┆ 6     ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ sol_c ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ lean_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 001_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 2.lcd ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _none ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 01.l… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _none ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 15.l… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Contr ┆ 4.6   ┆ 322.0 ┆ -0.07 ┆ 56.0  ┆ 4.567 ┆ 4.7   ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8 4d  ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ sol_n ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ one_0 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 01_01 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ .lcd  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A2  ┆ buf ┆ 30. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ fer ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _buff ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ er_00 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1_02… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A7  ┆ 5de ┆ 2.0 ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.483 ┆ 17497 ┆ 0.278 ┆ 5096. ┆ 4.367 ┆ 4.7   ┆ null  │
# │     ┆ g_5 ┆     ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A7  ┆ 5de ┆ 8.0 ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.484 ┆ 72813 ┆ 1.397 ┆ 21957 ┆ 4.417 ┆ 5.883 ┆ null  │
# │     ┆ g_5 ┆     ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A8  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.482 ┆ 91819 ┆ 1.781 ┆ 27238 ┆ 4.333 ┆ 4.783 ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.1 ┆ 3.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.413 ┆ 7391. ┆ 0.073 ┆ 2228. ┆ 4.35  ┆ 4.517 ┆ 0.11  │
# │     ┆ 1pm ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ _MS_QC ┆ _0.11 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ +Quant ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.1 ┆ 3.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.411 ┆ 7114. ┆ 0.068 ┆ 1993. ┆ 4.35  ┆ 4.567 ┆ 0.11  │
# │     ┆ 1pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.11 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.3 ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.423 ┆ 21860 ┆ 0.366 ┆ 6440. ┆ 4.35  ┆ 4.567 ┆ 0.33  │
# │     ┆ 3pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.33 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.3 ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.426 ┆ 21744 ┆ 0.364 ┆ 6361. ┆ 4.333 ┆ 4.567 ┆ 0.33  │
# │     ┆ 3pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.33 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 1pm ┆ 27. ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.42  ┆ 66732 ┆ 1.274 ┆ 19359 ┆ 4.35  ┆ 4.7   ┆ 1.0   │
# │     ┆ ol  ┆ 0   ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _1pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 1pm ┆ 27. ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.426 ┆ 60146 ┆ 1.141 ┆ 16968 ┆ 4.35  ┆ 4.583 ┆ 1.0   │
# │     ┆ ol  ┆ 0   ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _1pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.474 ┆ 21949 ┆ 0.368 ┆ 6439. ┆ 4.4   ┆ 4.733 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B8  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.468 ┆ 265.0 ┆ -0.07 ┆ 107.0 ┆ null  ┆ 4.517 ┆ null  │
# │     ┆ g_B ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆       ┆ 1     ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ deg_B ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 11.lc ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 27p ┆ 27. ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.416 ┆ 1.308 ┆ 26.4  ┆ 36999 ┆ 4.283 ┆ 4.7   ┆ 27.0  │
# │     ┆ mol ┆ 0   ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 549e6 ┆       ┆ 6.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _27pm ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ ABm1- ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ 4…    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 27p ┆ 27. ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.417 ┆ 1.288 ┆ 25.99 ┆ 37856 ┆ 4.35  ┆ 4.7   ┆ 27.0  │
# │     ┆ mol ┆ 0   ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 584e6 ┆ 6     ┆ 0.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _27pm ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ ABm1- ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ 4…    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 3pm ┆ 3.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.418 ┆ 15487 ┆ 3.057 ┆ 44843 ┆ 4.35  ┆ 4.667 ┆ 3.0   │
# │     ┆ ol  ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 9.0   ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _3pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 3pm ┆ 3.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.419 ┆ 15408 ┆ 3.041 ┆ 44683 ┆ 4.35  ┆ 4.7   ┆ 3.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 7.0   ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _3pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.424 ┆ 48421 ┆ 9.721 ┆ 13271 ┆ 4.133 ┆ 4.7   ┆ 9.0   │
# │     ┆ ol  ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 7.0   ┆       ┆ 8.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.419 ┆ 46739 ┆ 9.381 ┆ 13430 ┆ 4.333 ┆ 4.7   ┆ 9.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 8.0   ┆       ┆ 4.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.484 ┆ 10213 ┆ 1.99  ┆ 29885 ┆ 4.4   ┆ 4.783 ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ 1.0   ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ D7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.481 ┆ 14678 ┆ 0.221 ┆ 4439. ┆ 4.4   ┆ 4.6   ┆ null  │
# │     ┆ g_5 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ E7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.482 ┆ 21627 ┆ 0.361 ┆ 6490. ┆ 4.4   ┆ 4.733 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ F7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.474 ┆ 10825 ┆ 2.114 ┆ 30094 ┆ 4.35  ┆ 5.15  ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ 0.0   ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ G7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.481 ┆ 10819 ┆ 2.113 ┆ 31737 ┆ 4.417 ┆ 4.917 ┆ null  │
# │     ┆ g_5 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ 8.0   ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _4  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ H7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.474 ┆ 29587 ┆ 0.522 ┆ 8437. ┆ 4.233 ┆ 4.667 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %% [markdown]
# ## Chromatograms

# %%
path='Raw data/250328 5deg sol/all chromatograms/'
list_of_UV_chrom=[]
for root, dirs, files in os.walk(path):
    for name in files:
        if '.txt' in name:
            list_of_UV_chrom.append(name)
list_of_UV_chrom.sort(reverse=True)

# %%
data_UV = {}
for name in list_of_UV_chrom:
    if 'checkpoint' not in name:
        start_line_205 = pl.read_csv(path+name).with_row_index().filter(pl.col('[Header]')=='Wavelength(nm)	205nm')['index'][0]+2
        end_line_205 = pl.read_csv(path+name).with_row_index().filter(pl.col('[Header]')=='[LC Chromatogram(Detector A-Ch2)]')['index'][0]-1

        start_line_280 = pl.read_csv(path+name).with_row_index().filter(pl.col('[Header]')=='Wavelength(nm)	280nm')['index'][0]+2
        
        data_UV[name+'_205nm'] = pl.read_csv(path+name,separator='\t', skip_rows=start_line_205,n_rows=end_line_205-start_line_205,new_columns=['Time (min)','Abs (µAu)'],ignore_errors=True)
        data_UV[name+'_280nm'] = pl.read_csv(path+name,separator='\t', skip_rows=start_line_280,n_rows=end_line_205-start_line_205,new_columns=['Time (min)','Abs (µAu)'],ignore_errors=True)

# %%
pl.read_csv(path+name,separator='\t', skip_rows=start_line_205,n_rows=end_line_205-start_line_205,new_columns=['Time (min)','Abs (µAu)'],ignore_errors=True)
# Out:
# shape: (9_001, 2)
# ┌────────────┬───────────┐
# │ Time (min) ┆ Abs (µAu) │
# │ ---        ┆ ---       │
# │ f64        ┆ i64       │
# ╞════════════╪═══════════╡
# │ 0.0        ┆ -1313     │
# │ 0.00167    ┆ -1313     │
# │ 0.00333    ┆ -1316     │
# │ 0.005      ┆ -1319     │
# │ 0.00667    ┆ -1322     │
# │ 0.00833    ┆ -1326     │
# │ 0.01       ┆ -1330     │
# │ 0.01167    ┆ -2        │
# │ 0.01333    ┆ -7        │
# │ 0.015      ┆ -12       │
# │ 0.01667    ┆ -18       │
# │ 0.01833    ┆ -23       │
# │ 0.02       ┆ -30       │
# │ 0.02167    ┆ -3        │
# │ 0.02333    ┆ -7        │
# │ …          ┆ …         │
# │ 14.97667   ┆ 634       │
# │ 14.97833   ┆ 626       │
# │ 14.98      ┆ 616       │
# │ 14.98167   ┆ 605       │
# │ 14.98333   ┆ 594       │
# │ 14.985     ┆ 580       │
# │ 14.98667   ┆ 564       │
# │ 14.98833   ┆ 548       │
# │ 14.99      ┆ 535       │
# │ 14.99167   ┆ 522       │
# │ 14.99333   ┆ 511       │
# │ 14.995     ┆ 498       │
# │ 14.99667   ┆ 486       │
# │ 14.99833   ┆ 473       │
# │ 15.0       ┆ 458       │
# └────────────┴───────────┘

# %%
data_MS = {}
for name in list_of_UV_chrom:
    if 'checkpoint' not in name:
        start_line_MS = pl.read_csv(path+name).with_row_index().filter(pl.col('[Header]')=='m/z	1-2MS(E+) TIC')['index'][0]+6
        end_line_MS = pl.read_csv(path+name).with_row_index().filter(pl.col('[Header]')=='[Peak Table(Detector A-Ch1)]')['index'][0]-1

        
        data_MS[name+'_MS-TIC'] = pl.read_csv(path+name,separator='\t', skip_rows=start_line_MS,n_rows=end_line_MS-start_line_MS,new_columns=['Time (min)','Absolute Intensity','Relative Intensity'],ignore_errors=True,truncate_ragged_lines=True)
       # data_UV[name+'_280nm'] = pl.read_csv(path+name,separator='\t', skip_rows=start_line_280,n_rows=end_line_205-start_line_205,new_columns=['Time (min)','Abs (µAu)'],ignore_errors=True)

# %%
path='Raw data/240428 std curve/chromatograms/'
list_of_std_chrom=[]
for root, dirs, files in os.walk(path):
    for name in files:
        if '.txt' in name:
            list_of_std_chrom.append(name)
list_of_std_chrom.sort(reverse=True)

# %%
for name in list_of_std_chrom:
    if 'checkpoint' not in name:
        start_line_205 = pl.read_csv(path+name).with_row_index().filter(pl.col('[Header]')=='Wavelength(nm)	205nm')['index'][0]+2
        end_line_205 = pl.read_csv(path+name).with_row_index().filter(pl.col('[Header]')=='[LC Chromatogram(Detector A-Ch2)]')['index'][0]-1

        start_line_280 = pl.read_csv(path+name).with_row_index().filter(pl.col('[Header]')=='Wavelength(nm)	280nm')['index'][0]+2
        
        data_UV[name+'_205nm'] = pl.read_csv(path+name,separator='\t', skip_rows=start_line_205,n_rows=end_line_205-start_line_205,new_columns=['Time (min)','Abs (µAu)'],ignore_errors=True)
        data_UV[name+'_280nm'] = pl.read_csv(path+name,separator='\t', skip_rows=start_line_280,n_rows=end_line_205-start_line_205,new_columns=['Time (min)','Abs (µAu)'],ignore_errors=True)

# %%
for name in list_of_std_chrom:
    if 'checkpoint' not in name:
        start_line_MS = pl.read_csv(path+name).with_row_index().filter(pl.col('[Header]')=='m/z	1-2MS(E+) TIC')['index'][0]+6
        end_line_MS = pl.read_csv(path+name).with_row_index().filter(pl.col('[Header]')=='[Peak Table(Detector A-Ch1)]')['index'][0]-1

        
        data_MS[name+'_MS-TIC'] = pl.read_csv(path+name,separator='\t', skip_rows=start_line_MS,n_rows=end_line_MS-start_line_MS,new_columns=['Time (min)','Absolute Intensity','Relative Intensity'],ignore_errors=True,truncate_ragged_lines=True)
       # data_UV[name+'_280nm'] = pl.read_csv(path+name,separator='\t', skip_rows=start_line_280,n_rows=end_line_205-start_line_205,new_columns=['Time (min)','Abs (µAu)'],ignore_errors=True)

# %% [markdown]
# # Plot integrations & Calculate areas

# %% [markdown]
# ## UV

# %% [markdown]
# ### Standard curve

# %%
stds = UV.filter(pl.col('Sample Type')=='Standard(Calc.Point)').with_columns(
     pl.col('Std. Conc.').cast(pl.Float32),
     pl.col('Area').cast(pl.Float32),
     pl.col('Height').cast(pl.Float32)
)
stds
# Out:
# shape: (12, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ Via ┆ Sam ┆ Inj ┆ Method ┆ Data  ┆ Sampl ┆ Ret.  ┆ Area  ┆ Conc. ┆ Heigh ┆ Peak  ┆ Peak  ┆ Std.  │
# │ l#  ┆ ple ┆ .   ┆ File   ┆ Filen ┆ e     ┆ Time  ┆ ---   ┆ ---   ┆ t     ┆ Start ┆ End   ┆ Conc. │
# │ --- ┆ Nam ┆ Vol ┆ ---    ┆ ame   ┆ Type  ┆ ---   ┆ f32   ┆ f64   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ str ┆ e   ┆ ume ┆ str    ┆ ---   ┆ ---   ┆ f64   ┆       ┆       ┆ f32   ┆ f64   ┆ f64   ┆ f32   │
# │     ┆ --- ┆ --- ┆        ┆ str   ┆ str   ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ str ┆ f64 ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ B2  ┆ 0.1 ┆ 3.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.397 ┆ 2086. ┆ 0.088 ┆ 1277. ┆ 4.347 ┆ 4.435 ┆ 0.11  │
# │     ┆ 1pm ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ _MS_QC ┆ _0.11 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ +Quant ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.1 ┆ 3.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.395 ┆ 1872. ┆ 0.079 ┆ 1227. ┆ 4.362 ┆ 4.445 ┆ 0.11  │
# │     ┆ 1pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.11 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.3 ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.407 ┆ 9840. ┆ 0.394 ┆ 4726. ┆ 4.33  ┆ 4.488 ┆ 0.33  │
# │     ┆ 3pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.33 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.3 ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.412 ┆ 9363. ┆ 0.375 ┆ 4412. ┆ 4.357 ┆ 4.545 ┆ 0.33  │
# │     ┆ 3pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.33 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 1pm ┆ 27. ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.405 ┆ 26554 ┆ 1.053 ┆ 13510 ┆ 4.343 ┆ 4.49  ┆ 1.0   │
# │     ┆ ol  ┆ 0   ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _1pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 1pm ┆ 27. ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.41  ┆ 26119 ┆ 1.036 ┆ 13193 ┆ 4.34  ┆ 4.492 ┆ 1.0   │
# │     ┆ ol  ┆ 0   ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _1pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 27p ┆ 27. ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.4   ┆ 68051 ┆ 26.84 ┆ 30419 ┆ 4.095 ┆ 4.607 ┆ 27.0  │
# │     ┆ mol ┆ 0   ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 2.0   ┆ 5     ┆ 3.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _27pm ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ ABm1- ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ 4…    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 27p ┆ 27. ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.4   ┆ 67259 ┆ 26.53 ┆ 28948 ┆ 4.137 ┆ 4.605 ┆ 27.0  │
# │     ┆ mol ┆ 0   ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 3.0   ┆ 3     ┆ 1.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _27pm ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ ABm1- ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ 4…    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 3pm ┆ 3.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.4   ┆ 82947 ┆ 3.277 ┆ 33894 ┆ 4.135 ┆ 4.567 ┆ 3.0   │
# │     ┆ ol  ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _3pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 3pm ┆ 3.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.402 ┆ 72895 ┆ 2.88  ┆ 33999 ┆ 4.155 ┆ 4.485 ┆ 3.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _3pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.407 ┆ 23130 ┆ 9.128 ┆ 10651 ┆ 4.158 ┆ 4.592 ┆ 9.0   │
# │     ┆ ol  ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 0.0   ┆       ┆ 3.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.403 ┆ 23295 ┆ 9.193 ┆ 10752 ┆ 4.14  ┆ 4.588 ┆ 9.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0.0   ┆       ┆ 7.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
pos = [(i,j) for i in range(6) for j in range(2)]
#methods = ['UV','MS']
for zoom in [(1,7),(4,5)]:
    std_names=[]
    std_areas=[]
    fig, axs = plt.subplots(6,2,figsize=(7.5,10),sharey=False)
    #for n,df in enumerat([UV,MS]):
    summary=UV.filter(pl.col('Sample Type')=='Standard(Calc.Point)').sort(by='Std. Conc.')
    for i,name in enumerate(summary['Data Filename']):
        if summary.filter(pl.col('Data Filename')==name)['Peak Start'][0] != '-----':
    
            chrom_name = name.split('.lcd')[0]+'.txt'+'_205nm'
            peak_start = float(summary.filter(pl.col('Data Filename')==name)['Peak Start'][0])
            peak_end = float(summary.filter(pl.col('Data Filename')==name)['Peak End'][0])
            df=data_UV[chrom_name].filter(pl.col('Time (min)')>zoom[0]
                                         ).filter(pl.col('Time (min)')<zoom[1])
            x=np.array([df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][0],
                   df.filter(pl.col('Time (min)')>peak_start
                     ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][-1]])
            y=[df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Abs (µAu)'][0],
               df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Abs (µAu)'][-1]]
            slope, intercept = np.polyfit(x, y, 1)
            baseline = int(slope) * df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Time (min)'] + intercept
            
            axs[pos[i]].plot(df['Time (min)'],
                     df['Abs (µAu)'])
            poly_collect = axs[pos[i]].fill_between(df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Time (min)'],
                             df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Abs (µAu)'],
                            baseline,color='red')
            paths = poly_collect.get_paths()
            area = 0
            for path in paths:
                poly = Polygon(path.vertices)
                area += poly.area
            std_areas.append(area*60) # to get it in µAbs*s as in Labsolutions
            std_names.append(summary.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            axs[pos[i]].set_title(summary.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            axs[pos[i]].set_xlabel('Time / min')
            axs[pos[i]].set_ylabel('205 nm Abs')
        else:
            chrom_name = name.split('.lcd')[0]+'.txt'+'_205nm'
            df=data_UV[chrom_name].filter(pl.col('Time (min)')>zoom[0]
                                         ).filter(pl.col('Time (min)')<zoom[1])
           
            axs[pos[i]].plot(df['Time (min)'],
                     df['Abs (µAu)'])
            axs[pos[i]].set_title(summary.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            axs[pos[i]].set_xlabel('Time / min')
            axs[pos[i]].set_ylabel('205 nm Abs')
    plt.suptitle('Peak integrations for standard samples at 205 nm')
    plt.tight_layout()
    #plt.savefig('plots/260105 seeded temp sol/205nm integrations for samples at'+str(temp)+'degrees-original ints.pdf')

# %%
df= stds.sort(by='Std. Conc.')
std_curve = pl.DataFrame({
                'pmol':df['Std. Conc.'],
                'area':std_areas})
fit = np.polynomial.Polynomial.fit(std_curve['pmol'],std_curve['area'],deg=1).convert().coef
fit_w = np.polynomial.Polynomial.fit(std_curve['pmol'],std_curve['area'],deg=1,w=1/std_curve['pmol']).convert().coef
plt.scatter(std_curve['pmol'],std_curve['area'])
plt.plot(std_curve['pmol'],std_curve['pmol']*fit[1]+fit[0],label='Fit',c='black')
plt.plot(std_curve['pmol'],std_curve['pmol']*fit_w[1]+fit_w[0],label='Fit, weighted 1/x',c='darkorange')
plt.annotate('y='+str(round(fit[1]))+'x +'+str(round(fit[0])),
         (.1,.8),xycoords='axes fraction')
plt.annotate('y='+str(round(fit_w[1]))+'x '+str(round(fit_w[0])),
         (.1,.7),xycoords='axes fraction',c='darkorange')
plt.loglog()
plt.legend()
plt.xlabel('Amount / pmol')
plt.ylabel('Area / µAbs*s')
plt.tight_layout()
plt.title('Standard curve 205 nm')
std_curve_eq = fit_w

# %% [raw]
# ### Controls (no controls in this data set)

# %% [raw]
# UV.filter(pl.col('Data Filename').str.contains('QC')
#               ).filter(~pl.col('Vial#').str.contains('-1')
#               )

# %% [raw]
# name

# %% [raw]
# if UV.filter(pl.col('Data Filename')==name)['Peak Start'][0]:
#     print('yes')
# else:
#     print('no')

# %% [raw]
# for zoom in [(1,7),(4,5)]:
#     control_areas = []
#     control_names = []
#     control_inj_vols = []
#     fig, axs = plt.subplots(5,figsize=(7.5,10),sharey=False)
#
#     for n,name in enumerate(UV.filter(pl.col('Data Filename').str.contains('QC')
#                   ).filter(~pl.col('Vial#').str.contains('-1')
#                   )['Data Filename']):
#         if UV.filter(pl.col('Data Filename')==name)['Peak Start'][0]:
#
#             chrom_name = name.split('.lcd')[0]+'.txt'+'_205nm'
#             peak_start = float(UV.filter(pl.col('Data Filename')==name)['Peak Start'][0])
#             peak_end = float(UV.filter(pl.col('Data Filename')==name)['Peak End'][0])
#             df=data_UV[chrom_name].filter(pl.col('Time (min)')>zoom[0]
#                                          ).filter(pl.col('Time (min)')<zoom[1])
#             x=np.array([df.filter(pl.col('Time (min)')>peak_start
#                  ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][0],
#                    df.filter(pl.col('Time (min)')>peak_start
#                      ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][-1]])
#             y=[df.filter(pl.col('Time (min)')>peak_start
#                  ).filter(pl.col('Time (min)')<peak_end)['Abs (µAu)'][0],
#                df.filter(pl.col('Time (min)')>peak_start
#                  ).filter(pl.col('Time (min)')<peak_end)['Abs (µAu)'][-1]]
#             slope, intercept = np.polyfit(x, y, 1)
#             baseline = int(slope) * df.filter(pl.col('Time (min)')>peak_start
#                                          ).filter(pl.col('Time (min)')<peak_end)['Time (min)'] + intercept
#             # i=[int(UV.filter(pl.col('Data Filename')==name)['Sample Name'][0
#             #     ].split('_')[1] if UV.filter(pl.col('Data Filename')==name)['Sample Name'][0
#             #     ].split('_')[1]!='B' else 0)][0]
#             # if '2d' in name:
#             #     j=0
#             # if '7d' in name:
#             #     j=1
#             axs[n].plot(df['Time (min)'],
#                      df['Abs (µAu)'])
#             poly_collect = axs[n].fill_between(df.filter(pl.col('Time (min)')>peak_start
#                                          ).filter(pl.col('Time (min)')<peak_end)['Time (min)'],
#                              df.filter(pl.col('Time (min)')>peak_start
#                                          ).filter(pl.col('Time (min)')<peak_end)['Abs (µAu)'],
#                             baseline,color='red')
#             paths = poly_collect.get_paths()
#             area = 0
#             for path in paths:
#                 poly = Polygon(path.vertices)
#                 area += poly.area
#             control_areas.append(area*60) # to get it in µAbs*s as in Labsolutions
#             control_names.append(UV.filter(pl.col('Data Filename')==name)['Sample Name'][0])
#             control_inj_vols.append(UV.filter(pl.col('Data Filename')==name)['Inj. Volume'][0])
#
#             axs[n].set_title(UV.filter(pl.col('Data Filename')==name)['Sample Name'][0]+', Inj. Vol.='+
#                             str(UV.filter(pl.col('Data Filename')==name)['Inj. Volume'][0]))
#             axs[n].set_xlabel('Time / min')
#             axs[n].set_ylabel('205 nm Abs')
#         else:
#             chrom_name = name.split('.lcd')[0]+'.txt'+'_205nm'
#             df=data_UV[chrom_name].filter(pl.col('Time (min)')>zoom[0]
#                                          ).filter(pl.col('Time (min)')<zoom[1])
#             # i=[int(UV.filter(pl.col('Data Filename')==name)['Sample Name'][0
#             #     ].split('_')[1] if UV.filter(pl.col('Data Filename')==name)['Sample Name'][0
#             #     ].split('_')[1]!='B' else 0)][0]
#             # if '2d' in name:
#             #     j=0
#             # if '7d' in name:
#             #     j=1
#             axs[n].plot(df['Time (min)'],
#                      df['Abs (µAu)'])
#             axs[n].set_title(UV.filter(pl.col('Data Filename')==name)['Sample Name'][0]+', Inj. Vol.='+
#                             str(UV.filter(pl.col('Data Filename')==name)['Inj. Volume'][0])+' µl')
#             axs[n].set_xlabel('Time / min')
#             axs[n].set_ylabel('205 nm Abs')
#     plt.suptitle('Peak integrations for control samples at 205 nm')
#     plt.tight_layout()
#     plt.savefig('plots/240510 WideTemp/205 integrations for controls zoomed between '+str(zoom[0])+' and '+str(zoom[1])+'.pdf')

# %% [markdown]
# ### Samples

# %%
UV.with_columns(
    pl.col('Conc.')/pl.col('Inj. Volume')
).sort(by='Sample Name')
# Out:
# shape: (28, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ Via ┆ Sam ┆ Inj ┆ Method ┆ Data  ┆ Sampl ┆ Ret.  ┆ Area  ┆ Conc. ┆ Heigh ┆ Peak  ┆ Peak  ┆ Std.  │
# │ l#  ┆ ple ┆ .   ┆ File   ┆ Filen ┆ e     ┆ Time  ┆ ---   ┆ ---   ┆ t     ┆ Start ┆ End   ┆ Conc. │
# │ --- ┆ Nam ┆ Vol ┆ ---    ┆ ame   ┆ Type  ┆ ---   ┆ f64   ┆ f64   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ str ┆ e   ┆ ume ┆ str    ┆ ---   ┆ ---   ┆ f64   ┆       ┆       ┆ f64   ┆ f64   ┆ f64   ┆ f64   │
# │     ┆ --- ┆ --- ┆        ┆ str   ┆ str   ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ str ┆ f64 ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ B2  ┆ 0.1 ┆ 3.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.397 ┆ 2086. ┆ 0.029 ┆ 1277. ┆ 4.347 ┆ 4.435 ┆ 0.11  │
# │     ┆ 1pm ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆ 333   ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ _MS_QC ┆ _0.11 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ +Quant ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.1 ┆ 3.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.395 ┆ 1872. ┆ 0.026 ┆ 1227. ┆ 4.362 ┆ 4.445 ┆ 0.11  │
# │     ┆ 1pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆ 333   ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.11 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.3 ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.407 ┆ 9840. ┆ 0.043 ┆ 4726. ┆ 4.33  ┆ 4.488 ┆ 0.33  │
# │     ┆ 3pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆ 778   ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.33 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.3 ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.412 ┆ 9363. ┆ 0.041 ┆ 4412. ┆ 4.357 ┆ 4.545 ┆ 0.33  │
# │     ┆ 3pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆ 667   ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.33 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 1pm ┆ 27. ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.405 ┆ 26554 ┆ 0.039 ┆ 13510 ┆ 4.343 ┆ 4.49  ┆ 1.0   │
# │     ┆ ol  ┆ 0   ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _1pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 1pm ┆ 27. ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.41  ┆ 26119 ┆ 0.038 ┆ 13193 ┆ 4.34  ┆ 4.492 ┆ 1.0   │
# │     ┆ ol  ┆ 0   ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆ 37    ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _1pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 27p ┆ 27. ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.4   ┆ 68051 ┆ 0.994 ┆ 30419 ┆ 4.095 ┆ 4.607 ┆ 27.0  │
# │     ┆ mol ┆ 0   ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 2.0   ┆ 259   ┆ 3.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _27pm ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ ABm1- ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ 4…    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 27p ┆ 27. ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.4   ┆ 67259 ┆ 0.982 ┆ 28948 ┆ 4.137 ┆ 4.605 ┆ 27.0  │
# │     ┆ mol ┆ 0   ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 3.0   ┆ 704   ┆ 1.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _27pm ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ ABm1- ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ 4…    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 3pm ┆ 3.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.4   ┆ 82947 ┆ 1.092 ┆ 33894 ┆ 4.135 ┆ 4.567 ┆ 3.0   │
# │     ┆ ol  ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆ 333   ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _3pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 3pm ┆ 3.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.402 ┆ 72895 ┆ 0.96  ┆ 33999 ┆ 4.155 ┆ 4.485 ┆ 3.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _3pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.468 ┆ 47662 ┆ 0.188 ┆ 20537 ┆ 4.215 ┆ 4.552 ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆ 5     ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ F7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.458 ┆ 54012 ┆ 0.213 ┆ 22734 ┆ 4.203 ┆ 4.542 ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆ 6     ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A8  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.467 ┆ 47273 ┆ 0.187 ┆ 19347 ┆ 4.203 ┆ 4.55  ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.458 ┆ 15750 ┆ 0.062 ┆ 6109. ┆ 4.218 ┆ 4.542 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆ 7     ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ E7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.465 ┆ 11250 ┆ 0.044 ┆ 4403. ┆ 4.2   ┆ 4.538 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆ 9     ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ H7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.458 ┆ 11628 ┆ 0.046 ┆ 5990. ┆ 4.395 ┆ 4.547 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆ 4     ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A7  ┆ 5de ┆ 2.0 ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.468 ┆ 8625. ┆ 0.173 ┆ 4091. ┆ 4.403 ┆ 4.558 ┆ null  │
# │     ┆ g_5 ┆     ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A7  ┆ 5de ┆ 8.0 ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.468 ┆ 47994 ┆ 0.237 ┆ 19056 ┆ 4.205 ┆ 4.55  ┆ null  │
# │     ┆ g_5 ┆     ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆ 25    ┆ .0    ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ D7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.463 ┆ 6908. ┆ 0.027 ┆ 2789. ┆ 4.402 ┆ 4.595 ┆ null  │
# │     ┆ g_5 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ 0     ┆ 8     ┆ 0     ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ G7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.463 ┆ 54544 ┆ 0.215 ┆ 23531 ┆ 4.207 ┆ 4.548 ┆ null  │
# │     ┆ g_5 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆ 7     ┆ .0    ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _4  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B8  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ g_B ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ deg_B ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 11.lc ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.407 ┆ 23130 ┆ 1.014 ┆ 10651 ┆ 4.158 ┆ 4.592 ┆ 9.0   │
# │     ┆ ol  ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 0.0   ┆ 222   ┆ 3.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.403 ┆ 23295 ┆ 1.021 ┆ 10752 ┆ 4.14  ┆ 4.588 ┆ 9.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0.0   ┆ 444   ┆ 7.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ A2  ┆ buf ┆ 30. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ fer ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _buff ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ er_00 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1_02… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ cle ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Contr ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ an  ┆ 0   ┆ Soluti ┆ 8 4d  ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ sol_c ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ lean_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 001_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 2.lcd ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _none ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 01.l… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _none ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 15.l… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Contr ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8 4d  ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ sol_n ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ one_0 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 01_01 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ .lcd  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
# time='65h'
# t1 = UV.filter(pl.col('Sample Type')=="Unknown"
#          ).filter(pl.col('Data Filename').str.contains(time))
conc_to_row = {'12':0,
               '25':1,
               '50':2}

for zoom in [(1,7),(4,5)]:
    
    names=[]
    areas=[]
    inj_vols=[]

    #for temp in ['18','23','30','40','70']:
    #for time in ['65h','5days']:

    fig, axs = plt.subplots(3,4,figsize=(15,7.5),sharey=False)
    t_df = UV.filter(pl.col('Sample Type')=="Unknown"
     )
    
    for n,name in enumerate(t_df['Data Filename']):
        if t_df.filter(pl.col('Data Filename')==name)['Peak Start'][0]:
    
            chrom_name = name.split('.lcd')[0]+'.txt'+'_205nm'
            peak_start = float(UV.filter(pl.col('Data Filename')==name)['Peak Start'][0])
            peak_end = float(UV.filter(pl.col('Data Filename')==name)['Peak End'][0])
            df=data_UV[chrom_name].filter(pl.col('Time (min)')>zoom[0]
                                         ).filter(pl.col('Time (min)')<zoom[1])
            x=np.array([df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][0],
                   df.filter(pl.col('Time (min)')>peak_start
                     ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][-1]])
            y=[df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Abs (µAu)'][0],
               df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Abs (µAu)'][-1]]
            slope, intercept = np.polyfit(x, y, 1)
            baseline = int(slope) * df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Time (min)'] + intercept
            i=conc_to_row[(t_df.filter(pl.col('Data Filename')==name)['Sample Name'][0].split('_')[1][0]+
               t_df.filter(pl.col('Data Filename')==name)['Sample Name'][0].split('_')[1][1])]
            j=int(t_df.filter(pl.col('Data Filename')==name)['Sample Name'][0][-1])-1
          
            axs[i,j].plot(df['Time (min)'],
                     df['Abs (µAu)'])
            poly_collect = axs[i,j].fill_between(df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Time (min)'],
                             df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Abs (µAu)'],
                            baseline,color='red')
            paths = poly_collect.get_paths()
            area = 0
            for path in paths:
                poly = Polygon(path.vertices)
                area += poly.area
            areas.append(area*60) # to get it in µAbs*s as in Labsolutions
            names.append(UV.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            inj_vols.append(UV.filter(pl.col('Data Filename')==name)['Inj. Volume'][0])
            axs[i,j].set_title(UV.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            axs[i,j].set_xlabel('Time / min')
            axs[i,j].set_ylabel('205 nm Abs')
        else:
            chrom_name = name.split('.lcd')[0]+'.txt'+'_205nm'
            df=data_UV[chrom_name].filter(pl.col('Time (min)')>zoom[0]
                                         ).filter(pl.col('Time (min)')<zoom[1])
            i=0
            j=3
            axs[i,j].plot(df['Time (min)'],
                     df['Abs (µAu)'])
            axs[i,j].set_title(UV.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            axs[i,j].set_xlabel('Time / min')
            axs[i,j].set_ylabel('205 nm Abs')
    plt.suptitle('Peak integrations for samples at 4days at 205 nm')
    plt.tight_layout()
    plt.savefig('plots/250328 5deg sol/205nm integrations for samples at 4 days at 205 nm-zoomed between '+str(zoom[0])+' and '+str(zoom[1])+'.pdf')

# %% [markdown]
# ### Calc. Conc.

# %%
amounts_UV= pl.DataFrame({'Sample Name':names,
                           'Area (python)':areas,
                          'Inj. Vol.':inj_vols
                          # 'Amount (pmol)':[(areas-fit_w[0])/fit_w[1]]+[(control_areas-fit_w[0])/fit_w[1]], #amount (pmol) calculated from area and standard curve, divided by injection volume of 30 µl, times a 1000 to get nM
                            }).with_columns(
    ((pl.col('Area (python)')-fit_w[0])/fit_w[1]).alias('Amount (pmol)')
)
# conces_UV_man_int.with_columns(
#     (pl.col('Amount (pmol)')/pl.col('Inj. Vol.')*1000).alias('Conc. (nM)')
# )

# %%
amounts_UV
# Out:
# shape: (10, 4)
# ┌─────────────┬───────────────┬───────────┬───────────────┐
# │ Sample Name ┆ Area (python) ┆ Inj. Vol. ┆ Amount (pmol) │
# │ ---         ┆ ---           ┆ ---       ┆ ---           │
# │ str         ┆ f64           ┆ f64       ┆ f64           │
# ╞═════════════╪═══════════════╪═══════════╪═══════════════╡
# │ 5deg_50uM_1 ┆ 8629.22976    ┆ 2.0       ┆ 0.354165      │
# │ 5deg_50uM_2 ┆ 47886.106581  ┆ 8.0       ┆ 1.833647      │
# │ 5deg_12uM_3 ┆ 47141.136483  ┆ 10.0      ┆ 1.805571      │
# │ 5deg_25uM_1 ┆ 15824.893656  ┆ 10.0      ┆ 0.62535       │
# │ 5deg_12uM_1 ┆ 47610.697665  ┆ 10.0      ┆ 1.823268      │
# │ 5deg_50uM_3 ┆ 6825.00423    ┆ 10.0      ┆ 0.286169      │
# │ 5deg_25uM_2 ┆ 11296.02576   ┆ 10.0      ┆ 0.454669      │
# │ 5deg_12uM_2 ┆ 54097.792668  ┆ 10.0      ┆ 2.067748      │
# │ 5deg_50uM_4 ┆ 54428.015358  ┆ 10.0      ┆ 2.080194      │
# │ 5deg_25uM_3 ┆ 11587.30338   ┆ 10.0      ┆ 0.465647      │
# └─────────────┴───────────────┴───────────┴───────────────┘

# %%
concs_UV=amounts_UV.with_columns(
    (pl.col('Amount (pmol)')/pl.col('Inj. Vol.')*1000).alias('Conc. (nM)')
)
concs_UV
# Out:
# shape: (10, 5)
# ┌─────────────┬───────────────┬───────────┬───────────────┬────────────┐
# │ Sample Name ┆ Area (python) ┆ Inj. Vol. ┆ Amount (pmol) ┆ Conc. (nM) │
# │ ---         ┆ ---           ┆ ---       ┆ ---           ┆ ---        │
# │ str         ┆ f64           ┆ f64       ┆ f64           ┆ f64        │
# ╞═════════════╪═══════════════╪═══════════╪═══════════════╪════════════╡
# │ 5deg_50uM_1 ┆ 8629.22976    ┆ 2.0       ┆ 0.354165      ┆ 177.082595 │
# │ 5deg_50uM_2 ┆ 47886.106581  ┆ 8.0       ┆ 1.833647      ┆ 229.205906 │
# │ 5deg_12uM_3 ┆ 47141.136483  ┆ 10.0      ┆ 1.805571      ┆ 180.557141 │
# │ 5deg_25uM_1 ┆ 15824.893656  ┆ 10.0      ┆ 0.62535       ┆ 62.534967  │
# │ 5deg_12uM_1 ┆ 47610.697665  ┆ 10.0      ┆ 1.823268      ┆ 182.326786 │
# │ 5deg_50uM_3 ┆ 6825.00423    ┆ 10.0      ┆ 0.286169      ┆ 28.616897  │
# │ 5deg_25uM_2 ┆ 11296.02576   ┆ 10.0      ┆ 0.454669      ┆ 45.466928  │
# │ 5deg_12uM_2 ┆ 54097.792668  ┆ 10.0      ┆ 2.067748      ┆ 206.774835 │
# │ 5deg_50uM_4 ┆ 54428.015358  ┆ 10.0      ┆ 2.080194      ┆ 208.019353 │
# │ 5deg_25uM_3 ┆ 11587.30338   ┆ 10.0      ┆ 0.465647      ┆ 46.564672  │
# └─────────────┴───────────────┴───────────┴───────────────┴────────────┘

# %%
# corr_factor = (10000/
# concs_UV.filter(pl.col('Sample Name')=="10uM ABm1-42"
#                 )['Conc. (nM)'][0])
# corr_factor

# %%
# concs_UV=concs_UV.with_columns(
#     (pl.col('Conc. (nM)')*corr_factor).alias('Corr. Conc. (nM)')
# )

# %%
concs_UV.filter(~pl.col('Sample Name').str.contains('buffer')
                        ).filter(pl.col('Sample Name').str.contains('12')
                            )['Conc. (nM)'].to_numpy()
# Out:
# array([180.55714093, 182.3267859 , 206.77483543])

# %%
concs_UV.filter(pl.col('Sample Name').str.contains('_B'))
# Out:
# shape: (0, 5)
# ┌─────────────┬───────────────┬───────────┬───────────────┬────────────┐
# │ Sample Name ┆ Area (python) ┆ Inj. Vol. ┆ Amount (pmol) ┆ Conc. (nM) │
# │ ---         ┆ ---           ┆ ---       ┆ ---           ┆ ---        │
# │ str         ┆ f64           ┆ f64       ┆ f64           ┆ f64        │
# ╞═════════════╪═══════════════╪═══════════╪═══════════════╪════════════╡
# └─────────────┴───────────────┴───────────┴───────────────┴────────────┘

# %%
conc=12
y_t1=concs_UV.filter(pl.col('Sample Name').str.contains(conc)
                                        )['Conc. (nM)']#.to_numpy()
           
y_t1=y_t1.filter(y_t1>0).to_numpy()
y_t1
# Out:
# array([180.55714093, 182.3267859 , 206.77483543])

# %%
conces=[12,25,50]
t1=[]
#buffer_corr_t2=[]
temps_t1=[]
temps_t2=[]

for conc in conces:
    y_t1=concs_UV.filter(pl.col('Sample Name').str.contains(conc)
                                        )['Conc. (nM)']#.to_numpy()
           
    y_t1=y_t1.filter(y_t1>0).to_numpy()
    t1.append(y_t1)
    #temps_t1.append([int(temp)]*len(y_t1))
    
    plt.scatter([int(conc)]*len(y_t1),y_t1,color='green')
    
    

UV_values = pl.DataFrame({'Temp':[5]*len(t1),
                                           'Conc (nM)':t1,
                                           'Incubation time (days)':[4]*len(t1)
                                          })
plt.scatter(0,0,color='green',label='4 days')
#plt.scatter(0,0,color='blue',label='5 days')
plt.xlim(5,60)
plt.legend()
plt.xlabel('Initial Conc.')
plt.ylabel('Supernatant Concentration (nM)')
plt.title('205 nm - 4 days')
plt.tight_layout()
plt.savefig('plots/250328 5deg sol/205nm replicates.pdf')

# %%
UV_values.explode(['Conc (nM)']).write_csv('Processed data/250328 5deg sol/UV values 260122.csv')

# %% [markdown]
# ## MS

# %% [markdown]
# ### Standard curve

# %%
stds = MS.filter(pl.col('Sample Type')=='Standard(Calc.Point)').with_columns(
     pl.col('Std. Conc.').cast(pl.Float32),
     pl.col('Area').cast(pl.Float32),
     pl.col('Height').cast(pl.Float32)
)
stds
# Out:
# shape: (12, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ Via ┆ Sam ┆ Inj ┆ Method ┆ Data  ┆ Sampl ┆ Ret.  ┆ Area  ┆ Conc. ┆ Heigh ┆ Peak  ┆ Peak  ┆ Std.  │
# │ l#  ┆ ple ┆ .   ┆ File   ┆ Filen ┆ e     ┆ Time  ┆ ---   ┆ ---   ┆ t     ┆ Start ┆ End   ┆ Conc. │
# │ --- ┆ Nam ┆ Vol ┆ ---    ┆ ame   ┆ Type  ┆ ---   ┆ f32   ┆ f64   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ str ┆ e   ┆ ume ┆ str    ┆ ---   ┆ ---   ┆ f64   ┆       ┆       ┆ f32   ┆ f64   ┆ f64   ┆ f32   │
# │     ┆ --- ┆ --- ┆        ┆ str   ┆ str   ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ str ┆ f64 ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ B2  ┆ 0.1 ┆ 3.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.413 ┆ 7391. ┆ 0.073 ┆ 2228. ┆ 4.35  ┆ 4.517 ┆ 0.11  │
# │     ┆ 1pm ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ _MS_QC ┆ _0.11 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ +Quant ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.1 ┆ 3.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.411 ┆ 7114. ┆ 0.068 ┆ 1993. ┆ 4.35  ┆ 4.567 ┆ 0.11  │
# │     ┆ 1pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 0     ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.11 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.3 ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.423 ┆ 21860 ┆ 0.366 ┆ 6440. ┆ 4.35  ┆ 4.567 ┆ 0.33  │
# │     ┆ 3pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.33 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 0.3 ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.426 ┆ 21744 ┆ 0.364 ┆ 6361. ┆ 4.333 ┆ 4.567 ┆ 0.33  │
# │     ┆ 3pm ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ ol  ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ta\Max ┆ _0.33 ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ \BioSh ┆ pmol  ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ …      ┆ ABm1… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 1pm ┆ 27. ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.42  ┆ 66732 ┆ 1.274 ┆ 19359 ┆ 4.35  ┆ 4.7   ┆ 1.0   │
# │     ┆ ol  ┆ 0   ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _1pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ B2  ┆ 1pm ┆ 27. ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.426 ┆ 60146 ┆ 1.141 ┆ 16968 ┆ 4.35  ┆ 4.583 ┆ 1.0   │
# │     ┆ ol  ┆ 0   ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ .0    ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _1pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 27p ┆ 27. ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.416 ┆ 1.308 ┆ 26.4  ┆ 36999 ┆ 4.283 ┆ 4.7   ┆ 27.0  │
# │     ┆ mol ┆ 0   ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 549e6 ┆       ┆ 6.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _27pm ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ ABm1- ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ 4…    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 27p ┆ 27. ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.417 ┆ 1.288 ┆ 25.99 ┆ 37856 ┆ 4.35  ┆ 4.7   ┆ 27.0  │
# │     ┆ mol ┆ 0   ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 584e6 ┆ 6     ┆ 0.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _27pm ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ ol    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ ABm1- ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ 4…    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 3pm ┆ 3.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.418 ┆ 15487 ┆ 3.057 ┆ 44843 ┆ 4.35  ┆ 4.667 ┆ 3.0   │
# │     ┆ ol  ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 9.0   ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _3pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 3pm ┆ 3.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.419 ┆ 15408 ┆ 3.041 ┆ 44683 ┆ 4.35  ┆ 4.7   ┆ 3.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 7.0   ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _3pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ BioShe ┆ 24042 ┆ Stand ┆ 4.424 ┆ 48421 ┆ 9.721 ┆ 13271 ┆ 4.133 ┆ 4.7   ┆ 9.0   │
# │     ┆ ol  ┆     ┆ ll_AB( ┆ 8-std ┆ ard(C ┆       ┆ 7.0   ┆       ┆ 8.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ M1-42) ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ _MS_QC ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ +Quant ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.419 ┆ 46739 ┆ 9.381 ┆ 13430 ┆ 4.333 ┆ 4.7   ┆ 9.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 8.0   ┆       ┆ 4.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
summaryMS
# Out:
# shape: (25, 17)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬───┬─────┬─────┬─────┬─────┬─────┬────────┬───────┐
# │     ┆ Dat ┆ Sam ┆ Sam ┆ Via ┆ Ret ┆ Are ┆ Con ┆ … ┆ Acc ┆ Cal ┆ Pea ┆ Pea ┆ Qua ┆ S/N    ┆ Taili │
# │ --- ┆ a   ┆ ple ┆ ple ┆ l#  ┆ .   ┆ a   ┆ c.  ┆   ┆ ura ┆ .   ┆ k   ┆ k   ┆ nt. ┆ ---    ┆ ng F. │
# │ i64 ┆ Fil ┆ Typ ┆ Nam ┆ --- ┆ Tim ┆ --- ┆ --- ┆   ┆ cy[ ┆ Poi ┆ Sta ┆ End ┆ Lim ┆ f64    ┆ ---   │
# │     ┆ ena ┆ e   ┆ e   ┆ str ┆ e   ┆ f64 ┆ f64 ┆   ┆ %]  ┆ nt  ┆ rt  ┆ --- ┆ it( ┆        ┆ str   │
┆       │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴───┴─────┴─────┴─────┴─────┴─────┴────────┴───────┘

# %%
data_MS['240428-std curve_27pmol ABm1-42_001_13.txt_MS-TIC']
# Out:
# shape: (870, 3)
# ┌────────────┬────────────────────┬────────────────────┐
# │ Time (min) ┆ Absolute Intensity ┆ Relative Intensity │
# │ ---        ┆ ---                ┆ ---                │
# │ f64        ┆ i64                ┆ f64                │
# ╞════════════╪════════════════════╪════════════════════╡
# │ 0.5        ┆ 4331               ┆ 1.15               │
# │ 0.517      ┆ 4415               ┆ 1.18               │
# │ 0.533      ┆ 4437               ┆ 1.18               │
# │ 0.55       ┆ 4411               ┆ 1.18               │
# │ 0.567      ┆ 4409               ┆ 1.18               │
# │ 0.583      ┆ 4453               ┆ 1.19               │
# │ 0.6        ┆ 4596               ┆ 1.23               │
# │ 0.617      ┆ 4769               ┆ 1.27               │
# │ 0.633      ┆ 4744               ┆ 1.27               │
# │ 0.65       ┆ 4613               ┆ 1.23               │
# │ 0.667      ┆ 4624               ┆ 1.23               │
# │ 0.683      ┆ 4654               ┆ 1.24               │
# │ 0.7        ┆ 4578               ┆ 1.22               │
# │ 0.717      ┆ 4555               ┆ 1.21               │
# │ 0.733      ┆ 4605               ┆ 1.23               │
# │ …          ┆ …                  ┆ …                  │
# │ 14.75      ┆ 4839               ┆ 1.29               │
# │ 14.767     ┆ 4845               ┆ 1.29               │
# │ 14.783     ┆ 4908               ┆ 1.31               │
# │ 14.8       ┆ 4939               ┆ 1.32               │
# │ 14.817     ┆ 4915               ┆ 1.31               │
# │ 14.833     ┆ 4880               ┆ 1.3                │
# │ 14.85      ┆ 4842               ┆ 1.29               │
# │ 14.867     ┆ 4801               ┆ 1.28               │
# │ 14.883     ┆ 4801               ┆ 1.28               │
# │ 14.9       ┆ 4847               ┆ 1.29               │
# │ 14.917     ┆ 4894               ┆ 1.31               │
# │ 14.933     ┆ 4875               ┆ 1.3                │
# │ 14.95      ┆ 4838               ┆ 1.29               │
# │ 14.967     ┆ 4892               ┆ 1.3                │
# │ 14.983     ┆ 5011               ┆ 1.34               │
# └────────────┴────────────────────┴────────────────────┘

# %%
MS
# Out:
# shape: (28, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ Via ┆ Sam ┆ Inj ┆ Method ┆ Data  ┆ Sampl ┆ Ret.  ┆ Area  ┆ Conc. ┆ Heigh ┆ Peak  ┆ Peak  ┆ Std.  │
# │ l#  ┆ ple ┆ .   ┆ File   ┆ Filen ┆ e     ┆ Time  ┆ ---   ┆ ---   ┆ t     ┆ Start ┆ End   ┆ Conc. │
# │ --- ┆ Nam ┆ Vol ┆ ---    ┆ ame   ┆ Type  ┆ ---   ┆ f64   ┆ f64   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ str ┆ e   ┆ ume ┆ str    ┆ ---   ┆ ---   ┆ f64   ┆       ┆       ┆ f64   ┆ f64   ┆ f64   ┆ f64   │
# │     ┆ --- ┆ --- ┆        ┆ str   ┆ str   ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ str ┆ f64 ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ -1  ┆ cle ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Contr ┆ 4.283 ┆ 533.0 ┆ -0.06 ┆ 72.0  ┆ 4.25  ┆ 4.517 ┆ null  │
# │     ┆ an  ┆ 0   ┆ Soluti ┆ 8 4d  ┆ ol    ┆       ┆       ┆ 6     ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ sol_c ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ lean_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 001_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 2.lcd ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _none ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 01.l… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 24042 ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  ┆ null  │
# │     ┆ e   ┆ 0   ┆ Soluti ┆ 8-std ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ons\Da ┆ curve ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ ta\Max ┆ _none ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 15.l… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ -1  ┆ non ┆ 10. ┆ C:\Lab ┆ 25032 ┆
┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C2  ┆ 9pm ┆ 9.0 ┆ C:\Lab ┆ 24042 ┆ Stand ┆ 4.419 ┆ 46739 ┆ 9.381 ┆ 13430 ┆ 4.333 ┆ 4.7   ┆ 9.0   │
# │     ┆ ol  ┆     ┆ Soluti ┆ 8-std ┆ ard(C ┆       ┆ 8.0   ┆       ┆ 4.0   ┆       ┆       ┆       │
# │     ┆ ABm ┆     ┆ ons\Da ┆ curve ┆ alc.P ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 1-4 ┆     ┆ ta\Max ┆ _9pmo ┆ oint) ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ 2   ┆     ┆ \BioSh ┆ l ABm ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ 1-42… ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ C7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.484 ┆ 10213 ┆ 1.99  ┆ 29885 ┆ 4.4   ┆ 4.783 ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ 1.0   ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _1  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ D7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.481 ┆ 14678 ┆ 0.221 ┆ 4439. ┆ 4.4   ┆ 4.6   ┆ null  │
# │     ┆ g_5 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ E7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.482 ┆ 21627 ┆ 0.361 ┆ 6490. ┆ 4.4   ┆ 4.733 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ F7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.474 ┆ 10825 ┆ 2.114 ┆ 30094 ┆ 4.35  ┆ 5.15  ┆ null  │
# │     ┆ g_1 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ 0.0   ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 2uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _2  ┆     ┆ ta\Max ┆ deg_1 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 2uM_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ G7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.481 ┆ 10819 ┆ 2.113 ┆ 31737 ┆ 4.417 ┆ 4.917 ┆ null  │
# │     ┆ g_5 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ 8.0   ┆       ┆ .0    ┆       ┆       ┆       │
# │     ┆ 0uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _4  ┆     ┆ ta\Max ┆ deg_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 0uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ H7  ┆ 5de ┆ 10. ┆ C:\Lab ┆ 25032 ┆ Unkno ┆ 4.474 ┆ 29587 ┆ 0.522 ┆ 8437. ┆ 4.233 ┆ 4.667 ┆ null  │
# │     ┆ g_2 ┆ 0   ┆ Soluti ┆ 8 4d  ┆ wn    ┆       ┆ .0    ┆       ┆ 0     ┆       ┆       ┆       │
# │     ┆ 5uM ┆     ┆ ons\Da ┆ sol_5 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ _3  ┆     ┆ ta\Max ┆ deg_2 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ \BioSh ┆ 5uM_3 ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆ …      ┆ _001_ ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ …     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
pos = [(i,j) for i in range(6) for j in range(2)]
#methods = ['UV','MS']
for zoom in [(1,7),(4,5)]:
    std_names=[]
    std_areas=[]
    fig, axs = plt.subplots(6,2,figsize=(7.5,10),sharey=False)
    #for n,df in enumerat([UV,MS]):
    summary=MS.filter(pl.col('Sample Type')=='Standard(Calc.Point)').sort(by='Std. Conc.')
    for i,name in enumerate(summary['Data Filename']):
        if summary.filter(pl.col('Data Filename')==name)['Peak Start'][0] != '-----':
    
            chrom_name = name.split('.lcd')[0]+'.txt'+'_MS-TIC'
            peak_start = float(summary.filter(pl.col('Data Filename')==name)['Peak Start'][0])
            peak_end = float(summary.filter(pl.col('Data Filename')==name)['Peak End'][0])
            df=data_MS[chrom_name].filter(pl.col('Time (min)')>zoom[0]
                                         ).filter(pl.col('Time (min)')<zoom[1])
            x=np.array([df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][0],
                   df.filter(pl.col('Time (min)')>peak_start
                     ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][-1]])
            y=[df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Absolute Intensity'][0],
               df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Absolute Intensity'][-1]]
            slope, intercept = np.polyfit(x, y, 1)
            baseline = int(slope) * df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Time (min)'] + intercept
            
            axs[pos[i]].plot(df['Time (min)'],
                     df['Absolute Intensity'])
            poly_collect = axs[pos[i]].fill_between(df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Time (min)'],
                             df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Absolute Intensity'],
                            baseline,color='red')
            paths = poly_collect.get_paths()
            area = 0
            for path in paths:
                poly = Polygon(path.vertices)
                area += poly.area
            std_areas.append(area*60) # to get it in A.U.*s as in Labsolutions?
            std_names.append(summary.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            axs[pos[i]].set_title(summary.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            axs[pos[i]].set_xlabel('Time / min')
            axs[pos[i]].set_ylabel('Absolute Intensity')
        else:
            chrom_name = name.split('.lcd')[0]+'.txt'+'_MS-TIC'
            df=data_MS[chrom_name].filter(pl.col('Time (min)')>zoom[0]
                                         ).filter(pl.col('Time (min)')<zoom[1])
           
            axs[pos[i]].plot(df['Time (min)'],
                     df['Absolute Intensity'])
            axs[pos[i]].set_title(summary.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            axs[pos[i]].set_xlabel('Time / min')
            axs[pos[i]].set_ylabel('Absolute Intensity')
    plt.suptitle('Peak integrations for standard samples -MS (SIM TIC)')
    plt.tight_layout()
    #plt.savefig('plots/260105 seeded temp sol/205nm integrations for samples at'+str(temp)+'degrees-original ints.pdf')

# %%
df= stds.sort(by='Std. Conc.')
std_curve = pl.DataFrame({
                'pmol':df['Std. Conc.'],
                'area':std_areas})
fit = np.polynomial.Polynomial.fit(std_curve['pmol'],std_curve['area'],deg=1).convert().coef
fit_w = np.polynomial.Polynomial.fit(std_curve['pmol'],std_curve['area'],deg=1,w=1/std_curve['pmol']).convert().coef
plt.scatter(std_curve['pmol'],std_curve['area'])
plt.plot(std_curve['pmol'],std_curve['pmol']*fit[1]+fit[0],label='Fit',c='black')
plt.plot(std_curve['pmol'],std_curve['pmol']*fit_w[1]+fit_w[0],label='Fit, weighted 1/x',c='darkorange')
plt.annotate('y='+str(round(fit[1]))+'x +'+str(round(fit[0])),
         (.1,.8),xycoords='axes fraction')
plt.annotate('y='+str(round(fit_w[1]))+'x +'+str(round(fit_w[0])),
         (.1,.7),xycoords='axes fraction',c='darkorange')
plt.loglog()
plt.legend()
plt.xlabel('Amount / pmol')
plt.ylabel('Area / a.u.*s')
plt.tight_layout()
plt.title('Standard curve MS')
std_curve_eq = fit_w

# %% [raw]
# ### Controls (no controls for this experiment)

# %% [raw]
# MS.filter(pl.col('Data Filename').str.contains('QC')
#               ).filter(~pl.col('Vial#').str.contains('-1')
#               )

# %% [raw]
# name

# %% [raw]
# if MS.filter(pl.col('Data Filename')==name)['Peak Start'][0]:
#     print('yes')
# else:
#     print('no')

# %% [raw]
# for zoom in [(1,7),(4,5)]:
#     control_areas = []
#     control_names = []
#     control_inj_vols = []
#     fig, axs = plt.subplots(5,figsize=(7.5,10),sharey=False)
#
#     for n,name in enumerate(MS.filter(pl.col('Data Filename').str.contains('QC')
#                   ).filter(~pl.col('Vial#').str.contains('-1')
#                   )['Data Filename']):
#         if MS.filter(pl.col('Data Filename')==name)['Peak Start'][0]:
#
#             chrom_name = name.split('.lcd')[0]+'.txt'+'_MS-TIC'
#             peak_start = float(MS.filter(pl.col('Data Filename')==name)['Peak Start'][0])
#             peak_end = float(MS.filter(pl.col('Data Filename')==name)['Peak End'][0])
#             df=data_MS[chrom_name].filter(pl.col('Time (min)')>zoom[0]
#                                          ).filter(pl.col('Time (min)')<zoom[1])
#             x=np.array([df.filter(pl.col('Time (min)')>peak_start
#                  ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][0],
#                    df.filter(pl.col('Time (min)')>peak_start
#                      ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][-1]])
#             y=[df.filter(pl.col('Time (min)')>peak_start
#                  ).filter(pl.col('Time (min)')<peak_end)['Absolute Intensity'][0],
#                df.filter(pl.col('Time (min)')>peak_start
#                  ).filter(pl.col('Time (min)')<peak_end)['Absolute Intensity'][-1]]
#             slope, intercept = np.polyfit(x, y, 1)
#             baseline = int(slope) * df.filter(pl.col('Time (min)')>peak_start
#                                          ).filter(pl.col('Time (min)')<peak_end)['Time (min)'] + intercept
#             # i=[int(UV.filter(pl.col('Data Filename')==name)['Sample Name'][0
#             #     ].split('_')[1] if UV.filter(pl.col('Data Filename')==name)['Sample Name'][0
#             #     ].split('_')[1]!='B' else 0)][0]
#             # if '2d' in name:
#             #     j=0
#             # if '7d' in name:
#             #     j=1
#             axs[n].plot(df['Time (min)'],
#                      df['Absolute Intensity'])
#             poly_collect = axs[n].fill_between(df.filter(pl.col('Time (min)')>peak_start
#                                          ).filter(pl.col('Time (min)')<peak_end)['Time (min)'],
#                              df.filter(pl.col('Time (min)')>peak_start
#                                          ).filter(pl.col('Time (min)')<peak_end)['Absolute Intensity'],
#                             baseline,color='red')
#             paths = poly_collect.get_paths()
#             area = 0
#             for path in paths:
#                 poly = Polygon(path.vertices)
#                 area += poly.area
#             control_areas.append(area*60) # to get it in µAbs*s as in Labsolutions
#             control_names.append(MS.filter(pl.col('Data Filename')==name)['Sample Name'][0])
#             control_inj_vols.append(MS.filter(pl.col('Data Filename')==name)['Inj. Volume'][0])
#
#             axs[n].set_title(MS.filter(pl.col('Data Filename')==name)['Sample Name'][0]+', Inj. Vol.='+
#                             str(MS.filter(pl.col('Data Filename')==name)['Inj. Volume'][0]))
#             axs[n].set_xlabel('Time / min')
#             axs[n].set_ylabel('Absolute Intensity')
#         else:
#             chrom_name = name.split('.lcd')[0]+'.txt'+'_MS-TIC'
#             df=data_MS[chrom_name].filter(pl.col('Time (min)')>zoom[0]
#                                          ).filter(pl.col('Time (min)')<zoom[1])
#             # i=[int(UV.filter(pl.col('Data Filename')==name)['Sample Name'][0
#             #     ].split('_')[1] if UV.filter(pl.col('Data Filename')==name)['Sample Name'][0
#             #     ].split('_')[1]!='B' else 0)][0]
#             # if '2d' in name:
#             #     j=0
#             # if '7d' in name:
#             #     j=1
#             axs[n].plot(df['Time (min)'],
#                      df['Absolute Intensity'])
#             axs[n].set_title(MS.filter(pl.col('Data Filename')==name)['Sample Name'][0]+', Inj. Vol.='+
#                             str(MS.filter(pl.col('Data Filename')==name)['Inj. Volume'][0])+' µl')
#             axs[n].set_xlabel('Time / min')
#             axs[n].set_ylabel('Absolute Intensity')
#     plt.suptitle('Peak integrations for control samples - MS')
#     plt.tight_layout()
#     plt.savefig('plots/240510 WideTemp/MS integrations for controls zoomed between '+str(zoom[0])+' and '+str(zoom[1])+'.pdf')

# %% [markdown]
# ### Samples

# %%
# time='65h'
# t1 = UV.filter(pl.col('Sample Type')=="Unknown"
#          ).filter(pl.col('Data Filename').str.contains(time))
conc_to_row = {'12':0,
               '25':1,
               '50':2}

for zoom in [(1,7),(4,5)]:
    
    names=[]
    areas=[]
    inj_vols=[]

    #for temp in ['18','23','30','40','70']:
    #for time in ['65h','5days']:

    fig, axs = plt.subplots(3,4,figsize=(15,7.5),sharey=False)
    t_df = MS.filter(pl.col('Sample Type')=="Unknown"
     )
    
    for n,name in enumerate(t_df['Data Filename']):
        if t_df.filter(pl.col('Data Filename')==name)['Peak Start'][0]:
    
            chrom_name = name.split('.lcd')[0]+'.txt'+'_MS-TIC'
            peak_start = float(MS.filter(pl.col('Data Filename')==name)['Peak Start'][0])
            peak_end = float(MS.filter(pl.col('Data Filename')==name)['Peak End'][0])
            df=data_MS[chrom_name].filter(pl.col('Time (min)')>zoom[0]
                                         ).filter(pl.col('Time (min)')<zoom[1])
            x=np.array([df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][0],
                   df.filter(pl.col('Time (min)')>peak_start
                     ).filter(pl.col('Time (min)')<peak_end)['Time (min)'][-1]])
            y=[df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Absolute Intensity'][0],
               df.filter(pl.col('Time (min)')>peak_start
                 ).filter(pl.col('Time (min)')<peak_end)['Absolute Intensity'][-1]]
            slope, intercept = np.polyfit(x, y, 1)
            baseline = int(slope) * df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Time (min)'] + intercept
            i=conc_to_row[(t_df.filter(pl.col('Data Filename')==name)['Sample Name'][0].split('_')[1][0]+
               t_df.filter(pl.col('Data Filename')==name)['Sample Name'][0].split('_')[1][1])]
            j=int(t_df.filter(pl.col('Data Filename')==name)['Sample Name'][0][-1])-1
            axs[i,j].plot(df['Time (min)'],
                     df['Absolute Intensity'])
            poly_collect = axs[i,j].fill_between(df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Time (min)'],
                             df.filter(pl.col('Time (min)')>peak_start
                                         ).filter(pl.col('Time (min)')<peak_end)['Absolute Intensity'],
                            baseline,color='red')
            paths = poly_collect.get_paths()
            area = 0
            for path in paths:
                poly = Polygon(path.vertices)
                area += poly.area
            areas.append(area*60) # to get it in µAbs*s as in Labsolutions
            names.append(MS.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            inj_vols.append(MS.filter(pl.col('Data Filename')==name)['Inj. Volume'][0])
            axs[i,j].set_title(MS.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            axs[i,j].set_xlabel('Time / min')
            axs[i,j].set_ylabel('Absolute Intensity')
        else:
            chrom_name = name.split('.lcd')[0]+'.txt'+'_MS-TIC'
            df=data_MS[chrom_name].filter(pl.col('Time (min)')>zoom[0]
                                         ).filter(pl.col('Time (min)')<zoom[1])
            i=0
            j=3
            axs[i,j].plot(df['Time (min)'],
                     df['Absolute Intensity'])
            axs[i,j].set_title(MS.filter(pl.col('Data Filename')==name)['Sample Name'][0])
            axs[i,j].set_xlabel('Time / min')
            axs[i,j].set_ylabel('Absolute Intensity')
    plt.suptitle('Peak integrations for samples at 4days - MS')
    plt.tight_layout()
    plt.savefig('plots/250328 5deg sol/MS integrations for samples at 4days -MS-zoomed between '+str(zoom[0])+' and '+str(zoom[1])+'.pdf')

# %% [markdown]
# ### Calc. Conc.

# %%
amounts_MS= pl.DataFrame({'Sample Name':names,
                           'Area (python)':areas,
                          'Inj. Vol.':inj_vols
                          # 'Amount (pmol)':[(areas-fit_w[0])/fit_w[1]]+[(control_areas-fit_w[0])/fit_w[1]], #amount (pmol) calculated from area and standard curve, divided by injection volume of 30 µl, times a 1000 to get nM
                            }).with_columns(
    ((pl.col('Area (python)')-fit_w[0])/fit_w[1]).alias('Amount (pmol)')
)
# conces_MS_man_int.with_columns(
#     (pl.col('Amount (pmol)')/pl.col('Inj. Vol.')*1000).alias('Conc. (nM)')
# )

# %%
amounts_MS
# Out:
# shape: (10, 4)
# ┌─────────────┬───────────────┬───────────┬───────────────┐
# │ Sample Name ┆ Area (python) ┆ Inj. Vol. ┆ Amount (pmol) │
# │ ---         ┆ ---           ┆ ---       ┆ ---           │
# │ str         ┆ f64           ┆ f64       ┆ f64           │
# ╞═════════════╪═══════════════╪═══════════╪═══════════════╡
# │ 5deg_50uM_1 ┆ 16602.918     ┆ 2.0       ┆ 0.292139      │
# │ 5deg_50uM_2 ┆ 68458.764     ┆ 8.0       ┆ 1.263732      │
# │ 5deg_12uM_3 ┆ 91409.42391   ┆ 10.0      ┆ 1.693745      │
# │ 5deg_25uM_1 ┆ 21754.416     ┆ 10.0      ┆ 0.388659      │
# │ 5deg_12uM_1 ┆ 99714.03      ┆ 10.0      ┆ 1.849344      │
# │ 5deg_50uM_3 ┆ 13854.99      ┆ 10.0      ┆ 0.240652      │
# │ 5deg_25uM_2 ┆ 21444.756     ┆ 10.0      ┆ 0.382857      │
# │ 5deg_12uM_2 ┆ 107835.69     ┆ 10.0      ┆ 2.001515      │
# │ 5deg_50uM_4 ┆ 98522.41092   ┆ 10.0      ┆ 1.827017      │
# │ 5deg_25uM_3 ┆ 28446.66      ┆ 10.0      ┆ 0.514048      │
# └─────────────┴───────────────┴───────────┴───────────────┘

# %%
concs_MS=amounts_MS.with_columns(
    (pl.col('Amount (pmol)')/pl.col('Inj. Vol.')*1000).alias('Conc. (nM)')
)
concs_MS#.filter(pl.col('Sample Name').str.contains('40')
                             #   )
# Out:
# shape: (10, 5)
# ┌─────────────┬───────────────┬───────────┬───────────────┬────────────┐
# │ Sample Name ┆ Area (python) ┆ Inj. Vol. ┆ Amount (pmol) ┆ Conc. (nM) │
# │ ---         ┆ ---           ┆ ---       ┆ ---           ┆ ---        │
# │ str         ┆ f64           ┆ f64       ┆ f64           ┆ f64        │
# ╞═════════════╪═══════════════╪═══════════╪═══════════════╪════════════╡
# │ 5deg_50uM_1 ┆ 16602.918     ┆ 2.0       ┆ 0.292139      ┆ 146.069311 │
# │ 5deg_50uM_2 ┆ 68458.764     ┆ 8.0       ┆ 1.263732      ┆ 157.9665   │
# │ 5deg_12uM_3 ┆ 91409.42391   ┆ 10.0      ┆ 1.693745      ┆ 169.374541 │
# │ 5deg_25uM_1 ┆ 21754.416     ┆ 10.0      ┆ 0.388659      ┆ 38.86593   │
# │ 5deg_12uM_1 ┆ 99714.03      ┆ 10.0      ┆ 1.849344      ┆ 184.934408 │
# │ 5deg_50uM_3 ┆ 13854.99      ┆ 10.0      ┆ 0.240652      ┆ 24.065226  │
# │ 5deg_25uM_2 ┆ 21444.756     ┆ 10.0      ┆ 0.382857      ┆ 38.285738  │
# │ 5deg_12uM_2 ┆ 107835.69     ┆ 10.0      ┆ 2.001515      ┆ 200.151498 │
# │ 5deg_50uM_4 ┆ 98522.41092   ┆ 10.0      ┆ 1.827017      ┆ 182.701739 │
# │ 5deg_25uM_3 ┆ 28446.66      ┆ 10.0      ┆ 0.514048      ┆ 51.404805  │
# └─────────────┴───────────────┴───────────┴───────────────┴────────────┘

# %%
# corr_factor = (10000/
# concs_MS.filter(pl.col('Sample Name')=="10uM ABm1-42"
#                 )['Conc. (nM)'][0])
# corr_factor

# %%
# concs_MS=concs_MS.with_columns(
#     (pl.col('Conc. (nM)')*corr_factor).alias('Conc. (nM)')
# )

# %%
# concs_MS.filter(~pl.col('Sample Name').str.contains('buffer')
#                         ).filter(pl.col('Sample Name').str.contains('70')
#                             ).filter(pl.col('Sample Name').str.contains('65h'))['Conc. (nM)'].to_numpy()

# %%
# concs_MS.filter(pl.col('Sample Name').str.contains('buffer'))

# %%
conces=[12,25,50]
t1=[]
#buffer_corr_t2=[]
temps_t1=[]
temps_t2=[]

for conc in conces:
    y_t1=concs_MS.filter(pl.col('Sample Name').str.contains(conc)
                                        )['Conc. (nM)']#.to_numpy()
           
    y_t1=y_t1.filter(y_t1>0).to_numpy()
    t1.append(y_t1)
    #temps_t1.append([int(temp)]*len(y_t1))
    
    plt.scatter([int(conc)]*len(y_t1),y_t1,color='green')
    
    

values = pl.DataFrame({'Temp':[5]*len(t1),
                                           'Conc (nM)':t1,
                                           'Incubation time (days)':[4]*len(t1)
                                          })
plt.scatter(0,0,color='green',label='4 days')
#plt.scatter(0,0,color='blue',label='5 days')
plt.xlim(5,60)
plt.legend()
plt.xlabel('Initial Conc.')
plt.ylabel('Supernatant Concentration (nM)')
plt.title('MS - 4 days')
plt.tight_layout()
plt.savefig('plots/250328 5deg sol/MS replicates.pdf')

# %%
values.explode(['Conc (nM)']).write_csv('Processed data/250328 5deg sol/MS values 260122.csv')
